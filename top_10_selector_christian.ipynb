# %% [markdown]
# # Top 10 selector

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import OneHotEncoder
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import TruncatedSVD
from sklearn.metrics.pairwise import cosine_similarity

# %%
df = pd.read_csv('data/2019_oct_sort_1000.csv')

# %%
df.head()
# Out:
#                 event_time event_type  product_id          category_id  \
# 0  2019-10-18 10:54:45 UTC       view    54900011  2146660887203676486
# 1  2019-10-18 10:55:20 UTC       view    54900011  2146660887203676486
# 2  2019-10-31 06:25:30 UTC       view     1005105  2053013555631882655
# 3  2019-10-31 06:25:52 UTC       view     5100816  2053013553375346967
# 4  2019-10-31 06:23:12 UTC       view     1005115  2053013555631882655
#
#             category_code   brand    price    user_id  \
# 0         apparel.costume     NaN    64.35  515483062
# 1         apparel.costume     NaN    64.35  515483062
# 2  electronics.smartphone   apple  1349.46  513782162
# 3                     NaN  xiaomi    29.60  513782162
# 4  electronics.smartphone   apple   955.84  513782162
#
#                            user_session
# 0  00000042-3e3f-42f9-810d-f3d264139c50
# 1  00000042-3e3f-42f9-810d-f3d264139c50
# 2  00000056-a206-40dd-b174-a072550fa38c
# 3  00000056-a206-40dd-b174-a072550fa38c
# 4  00000056-a206-40dd-b174-a072550fa38c

# %%
def preprocessing_feat(X):    
    X_preprocessed = X.dropna(subset = ['category_code', 'brand']) #tbd!!
    X_preprocessed = X_preprocessed.drop_duplicates()
    X_preprocessed['category_code'] = X_preprocessed['category_code'].str.replace('.',' ')
    return X_preprocessed

def pricing_criterion(X):
    pricing_guide = X.groupby('category_code')['price'].describe()[["25%", "75%"]].reset_index()
    X_merged = X.merge(pricing_guide, on="category_code", how="right")
    X_merged["price_category"] = X_merged.apply(lambda row: make_column(row), axis=1)
    return X_merged

def make_column(row):
    if row["price"] < row["25%"]:
        return "low"
    elif row["price"] < row["75%"]:
        return "medium"
    else:
        return "high"

def metadata(X):
    X['metadata'] = X[['category_code', 'brand', 'price_category']].apply(lambda x: ' '.join(x), axis = 1)
    return X

def rating(X):
    dct = {'view': 1, 'cart': 3, 'purchase': 5}
    X['rating'] = X['event_type'].map(dct)
    return X

# %%
X_prep = preprocessing_feat(df)
# Out:
# /tmp/ipykernel_852/3456390047.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   X_preprocessed['category_code'] = X_preprocessed['category_code'].str.replace('.',' ')

# %%
X_pric = pricing_criterion(X_prep)

# %%
X_pric.head()
# Out:
#                 event_time event_type  product_id          category_id  \
# 0  2019-10-09 21:41:23 UTC       view    49800017  2126679654801604876
# 1  2019-10-09 21:41:39 UTC       view    49800020  2126679654801604876
# 2  2019-10-09 16:37:32 UTC       view    28401080  2053013566209917945
# 3  2019-10-09 16:39:20 UTC       view    28401080  2053013566209917945
# 4  2019-10-09 16:42:31 UTC       view    28401080  2053013566209917945
#
#      category_code    brand  price    user_id  \
# 0  accessories bag   ritmix  12.32  537956308
# 1  accessories bag   ritmix  15.43  537956308
# 2  accessories bag  respect  66.67  516007189
# 3  accessories bag  respect  66.67  516007189
# 4  accessories bag  respect  66.67  516007189
#
#                            user_session    25%    75% price_category
# 0  00003599-a772-4c8a-9c22-0dfa4f6ecc83  15.43  66.67            low
# 1  00003599-a772-4c8a-9c22-0dfa4f6ecc83  15.43  66.67         medium
# 2  000037a4-c043-4113-9b53-7bbb5d7c2bfe  15.43  66.67           high
# 3  000037a4-c043-4113-9b53-7bbb5d7c2bfe  15.43  66.67           high
# 4  000037a4-c043-4113-9b53-7bbb5d7c2bfe  15.43  66.67           high

# %%
X_rating = rating(X_pric)

# %%
def metadata(X):
    X['metadata'] = X[['category_code', 'brand', 'price_category']].apply(lambda x: ' '.join(x), axis = 1)
    return X

# %%
X_meta = metadata(X_pric)
X_meta.head()
# Out:
#                 event_time event_type  product_id          category_id  \
# 0  2019-10-09 21:41:23 UTC       view    49800017  2126679654801604876
# 1  2019-10-09 21:41:39 UTC       view    49800020  2126679654801604876
# 2  2019-10-09 16:37:32 UTC       view    28401080  2053013566209917945
# 3  2019-10-09 16:39:20 UTC       view    28401080  2053013566209917945
# 4  2019-10-09 16:42:31 UTC       view    28401080  2053013566209917945
#
#      category_code    brand  price    user_id  \
# 0  accessories bag   ritmix  12.32  537956308
# 1  accessories bag   ritmix  15.43  537956308
# 2  accessories bag  respect  66.67  516007189
# 3  accessories bag  respect  66.67  516007189
# 4  accessories bag  respect  66.67  516007189
#
#                            user_session    25%    75% price_category  rating  \
# 0  00003599-a772-4c8a-9c22-0dfa4f6ecc83  15.43  66.67            low       1
# 1  00003599-a772-4c8a-9c22-0dfa4f6ecc83  15.43  66.67         medium       1
# 2  000037a4-c043-4113-9b53-7bbb5d7c2bfe  15.43  66.67           high       1
# 3  000037a4-c043-4113-9b53-7bbb5d7c2bfe  15.43  66.67           high       1
# 4  000037a4-c043-4113-9b53-7bbb5d7c2bfe  15.43  66.67           high       1
#
#                         metadata
# 0     accessories bag ritmix low
# 1  accessories bag ritmix medium
# 2   accessories bag respect high
# 3   accessories bag respect high
# 4   accessories bag respect high

# %%
X_rating.head()
# Out:
#                 event_time event_type  product_id          category_id  \
# 0  2019-10-09 21:41:23 UTC       view    49800017  2126679654801604876
# 1  2019-10-09 21:41:39 UTC       view    49800020  2126679654801604876
# 2  2019-10-09 16:37:32 UTC       view    28401080  2053013566209917945
# 3  2019-10-09 16:39:20 UTC       view    28401080  2053013566209917945
# 4  2019-10-09 16:42:31 UTC       view    28401080  2053013566209917945
#
#      category_code    brand  price    user_id  \
# 0  accessories bag   ritmix  12.32  537956308
# 1  accessories bag   ritmix  15.43  537956308
# 2  accessories bag  respect  66.67  516007189
# 3  accessories bag  respect  66.67  516007189
# 4  accessories bag  respect  66.67  516007189
#
#                            user_session    25%    75% price_category  rating  \
# 0  00003599-a772-4c8a-9c22-0dfa4f6ecc83  15.43  66.67            low       1
# 1  00003599-a772-4c8a-9c22-0dfa4f6ecc83  15.43  66.67         medium       1
# 2  000037a4-c043-4113-9b53-7bbb5d7c2bfe  15.43  66.67           high       1
# 3  000037a4-c043-4113-9b53-7bbb5d7c2bfe  15.43  66.67           high       1
# 4  000037a4-c043-4113-9b53-7bbb5d7c2bfe  15.43  66.67           high       1
#
#                         metadata
# 0     accessories bag ritmix low
# 1  accessories bag ritmix medium
# 2   accessories bag respect high
# 3   accessories bag respect high
# 4   accessories bag respect high

# %%
def ranking(X, n=5):
    X = pd.DataFrame(X_rating.groupby(by='product_id').rating.sum()).sort_values('rating', ascending=False).reset_index().index[0:n]
    return X

# %%
def top_n(product_id, X_rating, n=10):
    
    """select top n products by ranking'"""
    
    rating_idx = pd.DataFrame(X_rating.groupby(by='product_id').rating.sum()).sort_values('rating', ascending=False).reset_index().index[0:n]
    return rating_idx

    counter = 0
    
    for i in rating_idx:
        meta_text = X_rating[X_rating['product_id'] == i][['metadata']].iloc[0,:][0]
        
        if counter == 0:
            print(f"Top {n} recommendations for product_id {product_id}:")
            print(f"{i} - {meta_text} \n")
#             print("-----------------------")

        else:
            print(f"Rec {counter}) {i} - {meta_text}")
        
        counter += 1

# %%
X_rating.shape
# Out:
# (609, 14)

# %%
pd.DataFrame(X_rating.groupby(['product_id','brand']).rating.sum()).sort_values('rating', ascending=False)
# Out:
#                     rating
# product_id brand
# 1004767    samsung      48
# 1004856    samsung      25
# 1004834    samsung      22
# 1004870    samsung      21
# 1801881    samsung      15
# ...                    ...
# 2701646    indesit       1
# 2701673    indesit       1
# 2701773    indesit       1
# 2800477    beko          1
# 49800020   ritmix        1
#
# [310 rows x 1 columns]

# %%
pd.DataFrame(X_rating.groupby(['brand']).rating.sum()).sort_values('rating', ascending=False)
# Out:
#          rating
# brand
# samsung     262
# apple       112
# xiaomi       75
# oppo         20
# huawei       16
# ...         ...
# alteco        1
# karcher       1
# kenwood       1
# llorens       1
# zlatek        1
#
# [98 rows x 1 columns]

# %%
def top_n_overall(product_id, X_rating, n=5):
    
    """select top n products by ranking'"""
    
    rating_idx = pd.DataFrame(X_rating.groupby(by='product_id').rating.sum()).sort_values('rating', ascending=False).index[0:n]
#     rec_df.sort_values(ranking, ascending=False).index[0:n]
    counter = 0
    
    for i in rating_idx:
        meta_text = X_meta[X_meta['product_id'] == i][['metadata']].iloc[0,:][0]
        
        if counter == 0:
            print(f"Top {n} recommendations for product_id {product_id}:")
            print(f"{i} - {meta_text} \n")
#             print("-----------------------")

        else:
            print(f"Rec {counter}) {i} - {meta_text}")
        
        counter += 1

# %%
top_n_overall(49800017, X_rating)
# Out:
# Top 5 recommendations for product_id 49800017:
# 1004767 - electronics smartphone samsung medium
#
# Rec 1) 1004856 - electronics smartphone samsung low
# Rec 2) 1004834 - electronics smartphone samsung low
# Rec 3) 1004870 - electronics smartphone samsung medium
# Rec 4) 1801881 - electronics video tv samsung high

# %%
pd.DataFrame(X_rating.groupby(['product_id','brand']).rating.sum()).sort_values('rating', ascending=False)
# Out:
#                     rating
# product_id brand
# 1004767    samsung      48
# 1004856    samsung      25
# 1004834    samsung      22
# 1004870    samsung      21
# 1801881    samsung      15
# ...                    ...
# 2701646    indesit       1
# 2701673    indesit       1
# 2701773    indesit       1
# 2800477    beko          1
# 49800020   ritmix        1
#
# [310 rows x 1 columns]

# %%
def top_n_brands(X_rating, n=10):
    
    """select top n products by ranking'"""
    
    rating_idx =     pd.DataFrame(X_rating.groupby(['brand']).rating.sum()).sort_values('rating', ascending=False).index[0:n]

    #     rec_df.sort_values(ranking, ascending=False).index[0:n]
    return list(rating_idx)

# %%
top_n_brands(X_rating)
# Out:
# ['samsung',
#  'apple',
#  'xiaomi',
#  'oppo',
#  'huawei',
#  'tefal',
#  'indesit',
#  'starline',
#  'bts',
#  'respect']

# %%
def top_n_by_brand(X_rating, n=10):
    
    """select top n products by ranking'"""
    
    rating_idx = pd.DataFrame(X_rating.groupby(['product_id','brand']).rating.sum()).sort_values('rating', ascending=False)
    
    #     rec_df.sort_values(ranking, ascending=False).index[0:n]
    abc = rating_idx[rating_idx['brand']=='samsung']
    return abc

# %%
top_n_by_brand(X_rating)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages/pandas/core/indexes/base.py:3629, in Index.get_loc(self, key, method, tolerance)
#    3628 try:
# -> 3629     return self._engine.get_loc(casted_key)
#    3630 except KeyError as err:
#
# File ~/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages/pandas/_libs/index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages/pandas/_libs/index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'brand'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In [271], line 1
# ----> 1 top_n_by_brand(X_rating)
#
# Cell In [270], line 8, in top_n_by_brand(X_rating, n)
#       5 rating_idx = pd.DataFrame(X_rating.groupby(['product_id','brand']).rating.sum()).sort_values('rating', ascending=False)
#       7 #     rec_df.sort_values(ranking, ascending=False).index[0:n]
# ----> 8 abc = rating_idx[rating_idx['brand']=='samsung']
#       9 return abc
#
# File ~/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages/pandas/core/frame.py:3505, in DataFrame.__getitem__(self, key)
#    3503 if self.columns.nlevels > 1:
#    3504     return self._getitem_multilevel(key)
# -> 3505 indexer = self.columns.get_loc(key)
#    3506 if is_integer(indexer):
#    3507     indexer = [indexer]
#
# File ~/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages/pandas/core/indexes/base.py:3631, in Index.get_loc(self, key, method, tolerance)
#    3629     return self._engine.get_loc(casted_key)
#    3630 except KeyError as err:
# -> 3631     raise KeyError(key) from err
#    3632 except TypeError:
#    3633     # If we have a listlike key, _check_indexing_error will raise
#    3634     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3635     #  the TypeError.
#    3636     self._check_indexing_error(key)
#
# KeyError: 'brand'

# %%
top_n_by_brand(X_rating, brand='samsung')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages/pandas/core/indexes/base.py:3629, in Index.get_loc(self, key, method, tolerance)
#    3628 try:
# -> 3629     return self._engine.get_loc(casted_key)
#    3630 except KeyError as err:
#
# File ~/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages/pandas/_libs/index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages/pandas/_libs/index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'samsung'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In [258], line 1
# ----> 1 top_n_by_brand(X_rating, brand='samsung')
#
# Cell In [257], line 8, in top_n_by_brand(X_rating, brand, n)
#       5 rating_idx = pd.DataFrame(X_rating.groupby(['product_id','brand']).rating.sum()).sort_values('rating', ascending=False)
#       7 #     rec_df.sort_values(ranking, ascending=False).index[0:n]
# ----> 8 rating_idx = rating_idx[brand]
#       9 return rating_idx
#
# File ~/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages/pandas/core/frame.py:3505, in DataFrame.__getitem__(self, key)
#    3503 if self.columns.nlevels > 1:
#    3504     return self._getitem_multilevel(key)
# -> 3505 indexer = self.columns.get_loc(key)
#    3506 if is_integer(indexer):
#    3507     indexer = [indexer]
#
# File ~/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages/pandas/core/indexes/base.py:3631, in Index.get_loc(self, key, method, tolerance)
#    3629     return self._engine.get_loc(casted_key)
#    3630 except KeyError as err:
# -> 3631     raise KeyError(key) from err
#    3632 except TypeError:
#    3633     # If we have a listlike key, _check_indexing_error will raise
#    3634     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3635     #  the TypeError.
#    3636     self._check_indexing_error(key)
#
# KeyError: 'samsung'

# %%
pd.DataFrame(X_rating.groupby(['product_id','brand']).rating.sum()).sort_values('rating', ascending=False)
# Out:
#                     rating
# product_id brand
# 1004767    samsung      48
# 1004856    samsung      25
# 1004834    samsung      22
# 1004870    samsung      21
# 1801881    samsung      15
# ...                    ...
# 2701646    indesit       1
# 2701673    indesit       1
# 2701773    indesit       1
# 2800477    beko          1
# 49800020   ritmix        1
#
# [310 rows x 1 columns]

# %%
pd.DataFrame(X_rating.groupby(['product_id','brand']).rating.sum()).sort_values('rating', ascending=False)
# Out:
#                     rating
# product_id brand
# 1004767    samsung      48
# 1004856    samsung      25
# 1004834    samsung      22
# 1004870    samsung      21
# 1801881    samsung      15
# ...                    ...
# 2701646    indesit       1
# 2701673    indesit       1
# 2701773    indesit       1
# 2800477    beko          1
# 49800020   ritmix        1
#
# [310 rows x 1 columns]
