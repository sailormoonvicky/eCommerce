# 60500010  0.008190 -0.005175 -0.014780  0.010238 -0.005719 -0.001769
#
#                 48        49
# 1000978   0.039352 -0.287247
# 1001588   0.012112 -0.003206
# 1001606  -0.134516  0.169932
# 1002042   0.032258 -0.301445
# 1002062   0.032258 -0.301445
# ...            ...       ...
# 60500004 -0.098923 -0.014408
# 60500005 -0.098273 -0.018379
# 60500006 -0.098854 -0.018442
# 60500007 -0.099011 -0.015094
# 60500010 -0.098742 -0.018705
#
# [52817 rows x 50 columns]

# %%
df = pd.read_csv('../data/2019_oct_sort_1000.csv')

# %%
df.head()
# Out:
#                 event_time event_type  product_id          category_id  \
# 0  2019-10-18 10:54:45 UTC       view    54900011  2146660887203676486
# 1  2019-10-18 10:55:20 UTC       view    54900011  2146660887203676486
# 2  2019-10-31 06:25:30 UTC       view     1005105  2053013555631882655
# 3  2019-10-31 06:25:52 UTC       view     5100816  2053013553375346967
# 4  2019-10-31 06:23:12 UTC       view     1005115  2053013555631882655
#
#             category_code   brand    price    user_id  \
# 0         apparel.costume     NaN    64.35  515483062
# 1         apparel.costume     NaN    64.35  515483062
# 2  electronics.smartphone   apple  1349.46  513782162
# 3                     NaN  xiaomi    29.60  513782162
# 4  electronics.smartphone   apple   955.84  513782162
#
#                            user_session
# 0  00000042-3e3f-42f9-810d-f3d264139c50
# 1  00000042-3e3f-42f9-810d-f3d264139c50
# 2  00000056-a206-40dd-b174-a072550fa38c
# 3  00000056-a206-40dd-b174-a072550fa38c
# 4  00000056-a206-40dd-b174-a072550fa38c

# %%
# df.query("brand == 'apple' and category_code == 'sport bicycle'")  #check the dataframe output
df.query("product_id == 1002544")
# Out:
#                   event_time event_type  product_id          category_id  \
# 315  2019-10-03 12:19:29 UTC       view     1002544  2053013555631882655
# 394  2019-10-18 06:08:37 UTC       view     1002544  2053013555631882655
# 427  2019-10-19 11:09:48 UTC       view     1002544  2053013555631882655
# 428  2019-10-19 11:10:22 UTC   purchase     1002544  2053013555631882655
# 431  2019-10-19 11:10:52 UTC       view     1002544  2053013555631882655
# 627  2019-10-15 06:33:06 UTC       view     1002544  2053013555631882655
#
#               category_code  brand   price    user_id  \
# 315  electronics.smartphone  apple  462.40  554894341
# 394  electronics.smartphone  apple  460.07  546073764
# 427  electronics.smartphone  apple  460.05  561610048
# 428  electronics.smartphone  apple  460.05  561610048
# 431  electronics.smartphone  apple  460.05  561610048
# 627  electronics.smartphone  apple  460.50  553543505
#
#                              user_session
# 315  0000a6ff-132b-4efa-a52a-3f60a0e52be4
# 394  0000c887-335f-4500-a286-f2372daa9ecc
# 427  0000de39-dc74-414d-8da6-83ad56135bf5
# 428  0000de39-dc74-414d-8da6-83ad56135bf5
# 431  0000de39-dc74-414d-8da6-83ad56135bf5
# 627  00015b16-9528-4066-9bbf-c1da047d060b

# %%
def preprocessing_feat(X):    
    X_preprocessed = X.dropna(subset = ['category_code', 'brand']) #tbd!!
    X_preprocessed = X_preprocessed.drop_duplicates()
    X_preprocessed['category_code'] = X_preprocessed['category_code'].str.replace('.',' ')
    return X_preprocessed

def pricing_criterion(X):
    pricing_guide = X.groupby('category_code')['price'].describe()[["25%", "75%"]].reset_index()
    X_merged = X.merge(pricing_guide, on="category_code", how="right")
    X_merged["price_category"] = X_merged.apply(lambda row: make_column(row), axis=1)
    return X_merged

def make_column(row):
    if row["price"] < row["25%"]:
        return "low"
    elif row["price"] < row["75%"]:
        return "medium"
    else:
        return "high"

def metadata(X):
    X['metadata'] = X[['category_code', 'brand', 'price_category']].apply(lambda x: ' '.join(x), axis = 1)
    return X

def rating(X):
    dct = {'view': 1, 'cart': 3, 'purchase': 5}
    X['rating'] = X['event_type'].map(dct)
    return X

# %%
X_prep = preprocessing_feat(df)
# Out:
# /var/folders/6f/vn_j9pqn1qd8rp92y6x0h0hh0000gn/T/ipykernel_22835/3456390047.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   X_preprocessed['category_code'] = X_preprocessed['category_code'].str.replace('.',' ')

# %%
# X_prep.query("brand == 'apple' and category_code == 'sport bicycle'")  #check the dataframe output
X_prep.query("product_id == 4804718")
# Out:
# Empty DataFrame
# Columns: [event_time, event_type, product_id, category_id, category_code, brand, price, user_id, user_session]
# Index: []

# %%
X_pric = pricing_criterion(X_prep)

# %%
X_rating = rating(X_pric)

# %%
def metadata(X):
    X['metadata'] = X[['category_code', 'brand', 'price_category']].apply(lambda x: ' '.join(x), axis = 1)
    return X

# %%
X_meta = metadata(X_pric)

# %%
X_meta.query("brand == 'apple' and category_code == 'sport bicycle'")
# df_m.query("user_session == 'bde905b5-20f1-40ff-8ef6-a60d875e31e0'")
# Out:
# Empty DataFrame
# Columns: [event_time, event_type, product_id, category_id, category_code, brand, price, user_id, user_session, 25%, 75%, price_category, rating, metadata]
# Index: []

# %%
def ranking(X, n=5):
    X = pd.DataFrame(X_rating.groupby(by='product_id').rating.sum()).sort_values('rating', ascending=False).reset_index().index[0:n]
    return X

# %%
# def top_n(product_id, X_rating, n=10):
    
#     """select top n products by ranking'"""
    
#     rating_idx = pd.DataFrame(X_rating.groupby(by='product_id').rating.sum()).sort_values('rating', ascending=False).reset_index().index[0:n]
#     return rating_idx

#     counter = 0
    
#     for i in rating_idx:
#         meta_text = X_rating[X_rating['product_id'] == i][['metadata']].iloc[0,:][0]
        
#         if counter == 0:
#             print(f"Top {n} recommendations for product_id {product_id}:")
#             print(f"{i} - {meta_text} \n")
# #             print("-----------------------")

#         else:
#             print(f"Rec {counter}) {i} - {meta_text}")
        
#         counter += 1

# %%
def top_n_overall(product_id, X_rating, n=5):
    
    """select top n products by ranking'"""
    
    rating_idx = pd.DataFrame(X_rating.groupby(by='product_id').rating.sum()).sort_values('rating', ascending=False).index[0:n]
    #     rec_df.sort_values(ranking, ascending=False).index[0:n]
    counter = 0
    
    for i in rating_idx:
        meta_text = X_meta[X_meta['product_id'] == i][['metadata']].iloc[0,:][0]
        
        if counter == 0:
            print(f"Top {n} recommendations for product_id {product_id}:")
            print(f"{i} - {meta_text} \n")
#             print("-----------------------")

        else:
            print(f"Rec {counter}) {i} - {meta_text}")
        
        counter += 1

# %%
top_n_overall(49800017, X_rating)
# Out:
# Top 5 recommendations for product_id 49800017:
# 1004767 - electronics smartphone samsung medium
#
# Rec 1) 1004856 - electronics smartphone samsung low
# Rec 2) 1004834 - electronics smartphone samsung low
# Rec 3) 1004870 - electronics smartphone samsung medium
# Rec 4) 1801881 - electronics video tv samsung high

# %%
def top_n_brands(X_rating, n=20):
    
    """select top n products by ranking'"""
    
    rating_idx =     pd.DataFrame(X_rating.groupby(['brand']).rating.sum()).sort_values('rating', ascending=False).index[0:n]

    #     rec_df.sort_values(ranking, ascending=False).index[0:n]
    return list(rating_idx)

# %%
top_n_brands(X_rating)
# Out:
# ['samsung',
#  'apple',
#  'xiaomi',
#  'oppo',
#  'huawei',
#  'tefal',
#  'indesit',
#  'starline',
#  'bts',
#  'respect',
#  'artel',
#  'milavitsa',
#  'harper',
#  'haier',
#  'oasis',
#  'jbl',
#  'lenovo',
#  'ariston',
#  'nokia',
#  'sho-me']

# %%
def top_n_by_brand(X_rating, brand, n=10):
    
    """select top n products by brand'"""
    
    rating_idx = pd.DataFrame(X_rating.groupby(['product_id','brand']).rating.sum()).sort_values('rating', ascending=False).reset_index('brand')
    rating_idx = rating_idx[rating_idx['brand']==brand].index[0:n]
#     return rating_idx

    counter = 0

    for i in rating_idx:
            meta_text = X_meta[X_meta['product_id'] == i][['metadata']].iloc[0,:][0]

            if counter == 0:
                print(f"Top {n} recommendations for product_id {brand}:")
                print(f"{i} - {meta_text} \n")
    #             print("-----------------------")

            else:
                print(f"Rec {counter}) {i} - {meta_text}")

            counter += 1

# %%
top_n_by_brand(X_rating, brand='apple')
# Out:
# Top 10 recommendations for product_id apple:
# 4804056 - electronics audio headphone apple high
#
# Rec 1) 1004246 - electronics smartphone apple high
# Rec 2) 1002544 - electronics smartphone apple medium
# Rec 3) 1002633 - electronics smartphone apple medium
# Rec 4) 1004249 - electronics smartphone apple high
# Rec 5) 1005105 - electronics smartphone apple high
# Rec 6) 1003306 - electronics smartphone apple medium
# Rec 7) 1005135 - electronics smartphone apple high
# Rec 8) 1002540 - electronics smartphone apple medium
# Rec 9) 1005116 - electronics smartphone apple high
