# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import OneHotEncoder
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import TruncatedSVD
from sklearn.metrics.pairwise import cosine_similarity

from collections import Counter
import operator

# %%
filename = '../data/2019-Oct.csv_10%.csv'

# %%
1
# Out:
# 1

# %%
import random
p = 0.5  # 1% of the lines
# keep the header, then take only 1% of lines
# if random from [0,1] interval is greater than 0.01 the row will be skipped
df = pd.read_csv(
         filename,
         header=0, 
         skiprows=lambda i: i>0 and random.random() > p
)
df.shape
# Out:
# (2124617, 9)

# %% [markdown]
# # Preprocess

# %%
def preprocessing_feat(X, drop_event_time=False):
    if drop_event_time:
        X = X.drop("event_time", axis=1)
    
    X_preprocessed = X.dropna(subset = ['category_code', 'brand']) #tbd!!
    X_preprocessed = X_preprocessed.drop_duplicates()
    X_preprocessed['category_code'] = X_preprocessed['category_code'].str.replace('.',' ')
    return X_preprocessed

# %%
X_preprocessed = preprocessing_feat(df, drop_event_time=True)
# Out:
# /tmp/ipykernel_9601/4055017079.py:7: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   X_preprocessed['category_code'] = X_preprocessed['category_code'].str.replace('.',' ')

# %%
X_preprocessed.shape
# Out:
# (1293444, 8)

# %%
def make_column(row):
    if row["price"] < row["25%"]:
        return "low"
    elif row["price"] < row["75%"]:
        return "medium"
    else:
        return "high"

def pricing_criterion(X):
    pricing_guide = X.groupby('category_code')['price'].describe()[["25%", "75%"]].reset_index()
    X_merged = X.merge(pricing_guide, on="category_code", how="right")
    X_merged["price_category"] = X_merged.apply(lambda row: make_column(row), axis=1)
    return X_merged

# %%
X_merged = pricing_criterion(X_preprocessed)

# %%
def metadata(X):
    X['metadata'] = X[['category_code', 'brand', 'price_category']].apply(lambda x: ' '.join(x), axis = 1)
    return X

# %%
X_meta = metadata(X_merged)
X_meta.shape
# Out:
# (1293444, 12)

# %%
X_meta.head()
# Out:
#   event_type  product_id          category_id    category_code     brand  \
# 0       view    32900083  2055156924407612189  accessories bag   a-elita
# 1       view    28401176  2053013566209917945  accessories bag     karya
# 2       view    28400461  2053013566209917945  accessories bag  fabretti
# 3       view    28401054  2053013566209917945  accessories bag     karya
# 4       view    18300169  2053013558945383017  accessories bag        hp
#
#     price    user_id                          user_session    25%    75%  \
# 0    8.49  549437633  62760980-f427-42e0-a891-8b590fd54584  16.28  76.96
# 1  100.39  549348524  933c58ab-5185-44d6-94d6-c2ccb335d7f9  16.28  76.96
# 2   31.92  512406877  c1ae47b0-9ab4-4f5f-947a-2e0d80970e6c  16.28  76.96
# 3  100.39  514312434  0d0c3d87-ed6f-4f58-9b9e-2cc44b89d25c  16.28  76.96
# 4   17.82  555465687  1fa735b1-1d98-4562-9b7d-74211f89394a  16.28  76.96
#
#   price_category                         metadata
# 0            low      accessories bag a-elita low
# 1           high       accessories bag karya high
# 2         medium  accessories bag fabretti medium
# 3           high       accessories bag karya high
# 4         medium        accessories bag hp medium

# %%
filename = '../data/oct_final/X_meta_with_100pct_data_oct19.csv'

# %%
import random
p = 0.25  # 1% of the lines
# keep the header, then take only 1% of lines
# if random from [0,1] interval is greater than 0.01 the row will be skipped
df = pd.read_csv(
         filename,
         header=0, 
         skiprows=lambda i: i>0 and random.random() > p
)
df.shape
# Out:
# (1330380, 14)

# %%
X_meta = df

# %%
X_meta.shape
# Out:
# (1330380, 14)

# %%
X_meta.drop(columns=['product_id.1', 'Unnamed: 0'], inplace=True)

# %%
X_purch = X_meta[X_meta['event_type']=='purchase']

# %%
X_purch.head()
# Out:
#      product_id event_type          category_id    category_code      brand  \
# 18     28401176   purchase  2053013566209917945  accessories bag      karya
# 113    18300389   purchase  2053013558945383017  accessories bag  continent
# 415    28400930   purchase  2053013566209917945  accessories bag    respect
# 431    18300163   purchase  2053013558945383017  accessories bag     sumdex
# 778    28400774   purchase  2053013566209917945  accessories bag      baden
#
#       price    user_id                          user_session    25%    75%  \
# 18   100.39  512478069  a06ea679-2769-4ac8-ac2e-89225ed5e34b  16.32  76.96
# 113   36.01  541455363  efeb5712-ff06-4975-a6bd-8d690c6fb217  16.32  76.96
# 415   82.11  539475687  99948b73-fd37-43e7-89a5-e3ab35e4bcf7  16.32  76.96
# 431   19.53  531550634  b9f71ac1-3e4b-40f0-b1e0-f4e33387202e  16.32  76.96
# 778   46.08  512594229  8682b196-9fc7-49a0-82c2-35096419d731  16.32  76.96
#
#     price_category                          metadata
# 18            high        accessories bag karya high
# 113         medium  accessories bag continent medium
# 415           high      accessories bag respect high
# 431         medium     accessories bag sumdex medium
# 778         medium      accessories bag baden medium

# %%
def filter(X):
    df = pd.DataFrame(X.groupby('user_session').event_type.count())
    df_new = df[df['event_type']>1]
    return df_new

# %%
X_filter = filter(X_purch)

# %%
df_cross = X_purch[X_purch['user_session'].isin(X_filter.index)]

# %%
df_cross.head()
# Out:
#        product_id event_type          category_id  \
# 3240     18300088   purchase  2053013558945383017
# 34034    28715723   purchase  2053013565782098913
# 44850    28716214   purchase  2053013565069067197
# 44851    28716214   purchase  2053013565069067197
# 73817     6200717   purchase  2053013552293216471
#
#                            category_code    brand  price    user_id  \
# 3240                     accessories bag   sumdex  22.63  515867009
# 34034                      apparel shoes  caprice  64.61  562669160
# 44850                 apparel shoes keds  respect  66.67  555685958
# 44851                 apparel shoes keds  respect  66.67  555685958
# 73817  appliances environment air_heater    oasis   9.01  515577708
#
#                                user_session    25%     75% price_category  \
# 3240   a551d776-a1bf-4d1f-ac61-b8de424e9d88  16.32   76.96         medium
# 34034  a82f9713-d470-4b5e-bb79-256b2ffdd78b  62.81  105.54         medium
# 44850  21fdafde-1fa4-4805-9783-2273e30ec9c2  51.22  100.72         medium
# 44851  21fdafde-1fa4-4805-9783-2273e30ec9c2  51.22  100.72         medium
# 73817  d466a233-fe39-4974-ab93-96bb49862654  23.91   58.94            low
#
#                                           metadata
# 3240                 accessories bag sumdex medium
# 34034                 apparel shoes caprice medium
# 44850            apparel shoes keds respect medium
# 44851            apparel shoes keds respect medium
# 73817  appliances environment air_heater oasis low

# %% [markdown]
# # Counter

# %%
df_test = pd.DataFrame(df_cross.groupby('user_session')['product_id'].apply(list).tolist())
df_test.head()
# Out:
#          0        1   2   3
# 0  4804056  4804056 NaN NaN
# 1  4804056  1004249 NaN NaN
# 2  1005165  1005165 NaN NaN
# 3  3800106  3800106 NaN NaN
# 4  1004905  1004905 NaN NaN

# %%
def concat(X):
    X = X[X[0]!=X[1]]
    X['conc'] = X[0].astype(str) + '_' + X[1].astype(str)
    
    lst = list(X['conc'])
    
    a = list(Counter(lst).keys()) # equals to list(X['conc'])
    b = list(Counter(lst).values()) # counts the elements' frequency
    
    dct_1 = {a[i]: b[i] for i in range(len(a))}
    dct_2 = dict(sorted(dct_1.items(), key=operator.itemgetter(1),reverse=True))

    return pd.DataFrame.from_dict(dct_2, orient='index').reset_index().rename(columns={'index': 'combo', 0: 'counts'})

# %%
X_sell = concat(df_test)
# Out:
# /tmp/ipykernel_4847/1906696682.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['conc'] = X[0].astype(str) + '_' + X[1].astype(str)

# %%
X_sell
# Out:
#                 combo  counts
# 0     1004870_1004767       3
# 1     1004767_1004750       2
# 2     1004249_1003306       2
# 3     1004767_1004833       2
# 4     1004833_1004856       2
# ..                ...     ...
# 171   3801108_1004863       1
# 172  1004777_16200168       1
# 173   1802038_1801837       1
# 174   3200549_2900958       1
# 175   5800617_5801553       1
#
# [176 rows x 2 columns]

# %%
def x_seller(X):
    X["product_1"] = X["combo"].str.split("_",expand=True)[0].astype('category')
    X["product_2"] = X["combo"].str.split("_",expand=True)[1].astype('category')
    return X

# %%
new_dataframe = x_seller(X_sell)

new_dataframe.product_1 = new_dataframe.product_1.apply(lambda x: int(x))
new_dataframe.product_2 = new_dataframe.product_2.apply(lambda x: int(x))

# %%
new_df_1 = new_dataframe.merge(X_meta, how='left', left_on='product_1', right_on='product_id').rename(columns={'price': 'price_1', 'metadata': 'metadata_1'})

# %%
new_df_1.head()
# Out:
#              combo  counts  product_1 product_2  product_id event_type  \
# 0  1004870_1004767       3    1004870   1004767     1004870       view
# 1  1004870_1004767       3    1004870   1004767     1004870       view
# 2  1004870_1004767       3    1004870   1004767     1004870       view
# 3  1004870_1004767       3    1004870   1004767     1004870       view
# 4  1004870_1004767       3    1004870   1004767     1004870       view
#
#            category_id           category_code    brand  price_1    user_id  \
# 0  2053013555631882655  electronics smartphone  samsung   286.86  555461801
# 1  2053013555631882655  electronics smartphone  samsung   286.86  555461801
# 2  2053013555631882655  electronics smartphone  samsung   286.86  544148702
# 3  2053013555631882655  electronics smartphone  samsung   286.86  549849367
# 4  2053013555631882655  electronics smartphone  samsung   286.86  526595771
#
#                            user_session     25%     75% price_category  \
# 0  5e840781-e6f7-496d-a523-f7ad05c585a3  179.21  721.34         medium
# 1  5e840781-e6f7-496d-a523-f7ad05c585a3  179.21  721.34         medium
# 2  bc59e177-17c3-4495-bd40-23c2d3366e86  179.21  721.34         medium
# 3  a2d711f9-812d-40cf-bb15-761a9fd0e1b2  179.21  721.34         medium
# 4  7448d4c3-9cbb-4111-b953-5224419069ba  179.21  721.34         medium
#
#                               metadata_1
# 0  electronics smartphone samsung medium
# 1  electronics smartphone samsung medium
# 2  electronics smartphone samsung medium
# 3  electronics smartphone samsung medium
# 4  electronics smartphone samsung medium

# %%
new_df_1 = new_df_1.drop_duplicates(['product_1','product_2'])
new_df_1.shape
# Out:
# (176, 16)

# %%
new_df_1.head()
# Out:
#                  combo  counts  product_1 product_2  product_id event_type  \
# 0      1004870_1004767       3    1004870   1004767     1004870       view
# 11122  1004767_1004750       2    1004767   1004750     1004767       view
# 33195  1004249_1003306       2    1004249   1003306     1004249       view
# 44580  1004767_1004833       2    1004767   1004833     1004767       view
# 66653  1004833_1004856       2    1004833   1004856     1004833       view
#
#                category_id           category_code    brand  price_1  \
# 0      2053013555631882655  electronics smartphone  samsung   286.86
# 11122  2053013555631882655  electronics smartphone  samsung   254.82
# 33195  2053013555631882655  electronics smartphone    apple   739.81
# 44580  2053013555631882655  electronics smartphone  samsung   254.82
# 66653  2053013555631882655  electronics smartphone  samsung   174.76
#
#          user_id                          user_session     25%     75%  \
# 0      555461801  5e840781-e6f7-496d-a523-f7ad05c585a3  179.21  721.34
# 11122  512730342  4a34d086-4940-45e1-b70b-b04b1b8e96aa  179.21  721.34
# 33195  516298680  350a08d5-db6a-4d66-a7a8-284a8520754e  179.21  721.34
# 44580  512730342  4a34d086-4940-45e1-b70b-b04b1b8e96aa  179.21  721.34
# 66653  541414887  fcbaf678-f89e-4e2a-a5c4-b1c307640d31  179.21  721.34
#
#       price_category                             metadata_1
# 0             medium  electronics smartphone samsung medium
# 11122         medium  electronics smartphone samsung medium
# 33195           high      electronics smartphone apple high
# 44580         medium  electronics smartphone samsung medium
# 66653            low     electronics smartphone samsung low

# %%
df_short = new_df_1[['combo', 'counts', 'product_1', 'product_2', 'price_1', 'metadata_1']]
df_short.head()
# Out:
#                  combo  counts  product_1 product_2  price_1  \
# 0      1004870_1004767       3    1004870   1004767   286.86
# 11122  1004767_1004750       2    1004767   1004750   254.82
# 33195  1004249_1003306       2    1004249   1003306   739.81
# 44580  1004767_1004833       2    1004767   1004833   254.82
# 66653  1004833_1004856       2    1004833   1004856   174.76
#
#                                   metadata_1
# 0      electronics smartphone samsung medium
# 11122  electronics smartphone samsung medium
# 33195      electronics smartphone apple high
# 44580  electronics smartphone samsung medium
# 66653     electronics smartphone samsung low

# %%
df_final = df_short.merge(X_meta, how='left', left_on='product_2', right_on='product_id').rename(columns={'price': 'price_2', 'metadata': 'metadata_2'}).drop_duplicates(['product_1','product_2'])

# %%
df_final
# Out:
#                     combo  counts  product_1  product_2  price_1  \
# 0         1004870_1004767       3    1004870    1004767   286.86
# 22073     1004767_1004750       2    1004767    1004750   254.82
# 28218     1004249_1003306       2    1004249    1003306   739.81
# 34074     1004767_1004833       2    1004767    1004833   254.82
# 46068     1004833_1004856       2    1004833    1004856   174.76
# ...                   ...     ...        ...        ...      ...
# 1038203   3801108_1004863       1    3801108    1004863   386.08
# 1039905  1004777_16200168       1    1004777   16200168   136.40
# 1039909   1802038_1801837       1    1802038    1801837   195.37
# 1039988   3200549_2900958       1    3200549    2900958    25.71
# 1040539   5800617_5801553       1    5800617    5801553    20.85
#
#                                            metadata_1  product_id event_type  \
# 0               electronics smartphone samsung medium     1004767       view
# 22073           electronics smartphone samsung medium     1004750       view
# 28218               electronics smartphone apple high     1003306       view
# 34074           electronics smartphone samsung medium     1004833       view
# 46068              electronics smartphone samsung low     1004856       view
# ...                                               ...         ...        ...
# 1038203                    appliances iron braun high     1004863       view
# 1039905             electronics smartphone xiaomi low    16200168       view
# 1039909                  electronics video tv tcl low     1801837       view
# 1039988  appliances kitchen meat_grinder dauscher low     2900958       view
# 1040539          electronics audio subwoofer kicx low     5801553       view
#
#                  category_id                 category_code    brand  price_2  \
# 0        2053013555631882655        electronics smartphone  samsung   254.82
# 22073    2053013555631882655        electronics smartphone  samsung   197.43
# 28218    2053013555631882655        electronics smartphone    apple   588.77
# 34074    2053013555631882655        electronics smartphone  samsung   174.76
# 46068    2053013555631882655        electronics smartphone  samsung   130.76
# ...                      ...                           ...      ...      ...
# 1038203  2053013555631882655        electronics smartphone  samsung   174.76
# 1039905  2053013556344914381             kids fmcg diapers  huggies     2.63
# 1039909  2053013554415534427          electronics video tv    rebus   179.92
# 1039988  2053013554776244595  appliances kitchen microwave      arg    56.60
# 1040539  2053013553945772349   electronics audio subwoofer     kicx    22.39
#
#            user_id                          user_session       25%     75%  \
# 0        512730342  4a34d086-4940-45e1-b70b-b04b1b8e96aa  179.2100  721.34
# 22073    534079025  1f9ea674-626f-4ed8-a3e1-10afbf4f843d  179.2100  721.34
# 28218    513781008  ab1c76e1-94e1-47a2-9084-04e8be98e747  179.2100  721.34
# 34074    541414887  fcbaf678-f89e-4e2a-a5c4-b1c307640d31  179.2100  721.34
# 46068    552783882  0ac92940-754e-4cee-baaf-e6a1701a7062  179.2100  721.34
# ...            ...                                   ...       ...     ...
# 1038203  546953010  52438bd6-8549-4429-9819-2690bb891e57  179.2100  721.34
# 1039905  515535611  52ffe7a7-8976-4230-b480-751114c03e7d    9.0025   18.47
# 1039909  517672882  e96c4aa7-06fd-415c-a5d1-3087e5a95c0a  220.0100  496.48
# 1039988  555775937  bb8c29c8-c507-90a5-bc5f-4bae60d282a3   56.6000  115.58
# 1040539  513507199  e8096d04-9c2f-4978-9fab-3874645adabf   40.8800  126.13
#
#         price_category                               metadata_2
# 0               medium    electronics smartphone samsung medium
# 22073           medium    electronics smartphone samsung medium
# 28218           medium      electronics smartphone apple medium
# 34074              low       electronics smartphone samsung low
# 46068              low       electronics smartphone samsung low
# ...                ...                                      ...
# 1038203            low       electronics smartphone samsung low
# 1039905            low            kids fmcg diapers huggies low
# 1039909            low           electronics video tv rebus low
# 1039988         medium  appliances kitchen microwave arg medium
# 1040539            low     electronics audio subwoofer kicx low
#
# [176 rows x 18 columns]

# %% [markdown]
# # Final recommendation

# %%
df_final = df_final[['combo', 'counts', 'product_1', 'product_2', 'price_1', 'price_2', 'metadata_1', 'metadata_2']]

# %%
df_final
# Out:
#                     combo  counts  product_1  product_2  price_1  price_2  \
# 0         1004870_1004767       3    1004870    1004767   286.86   254.82
# 22073     1004767_1004750       2    1004767    1004750   254.82   197.43
# 28218     1004249_1003306       2    1004249    1003306   739.81   588.77
# 34074     1004767_1004833       2    1004767    1004833   254.82   174.76
# 46068     1004833_1004856       2    1004833    1004856   174.76   130.76
# ...                   ...     ...        ...        ...      ...      ...
# 1038203   3801108_1004863       1    3801108    1004863   386.08   174.76
# 1039905  1004777_16200168       1    1004777   16200168   136.40     2.63
# 1039909   1802038_1801837       1    1802038    1801837   195.37   179.92
# 1039988   3200549_2900958       1    3200549    2900958    25.71    56.60
# 1040539   5800617_5801553       1    5800617    5801553    20.85    22.39
#
#                                            metadata_1  \
# 0               electronics smartphone samsung medium
# 22073           electronics smartphone samsung medium
# 28218               electronics smartphone apple high
# 34074           electronics smartphone samsung medium
# 46068              electronics smartphone samsung low
# ...                                               ...
# 1038203                    appliances iron braun high
# 1039905             electronics smartphone xiaomi low
# 1039909                  electronics video tv tcl low
# 1039988  appliances kitchen meat_grinder dauscher low
# 1040539          electronics audio subwoofer kicx low
#
#                                       metadata_2
# 0          electronics smartphone samsung medium
# 22073      electronics smartphone samsung medium
# 28218        electronics smartphone apple medium
# 34074         electronics smartphone samsung low
# 46068         electronics smartphone samsung low
# ...                                          ...
# 1038203       electronics smartphone samsung low
# 1039905            kids fmcg diapers huggies low
# 1039909           electronics video tv rebus low
# 1039988  appliances kitchen microwave arg medium
# 1040539     electronics audio subwoofer kicx low
#
# [176 rows x 8 columns]

# %%
df_final = df_final[df_final['metadata_1'] != df_final['metadata_2']]

# %%
df_final.head()
# Out:
#                  combo  counts  product_1  product_2  price_1  price_2  \
# 28218  1004249_1003306       2    1004249    1003306   739.81   588.77
# 34074  1004767_1004833       2    1004767    1004833   254.82   174.76
# 71264  1004767_1004856       2    1004767    1004856   254.82   130.76
# 96460  4804056_1005159       2    4804056    1005159   161.98   231.41
# 99504  1004767_1005100       2    1004767    1005100   254.82   154.42
#
#                                    metadata_1  \
# 28218       electronics smartphone apple high
# 34074   electronics smartphone samsung medium
# 71264   electronics smartphone samsung medium
# 96460  electronics audio headphone apple high
# 99504   electronics smartphone samsung medium
#
#                                  metadata_2
# 28218   electronics smartphone apple medium
# 34074    electronics smartphone samsung low
# 71264    electronics smartphone samsung low
# 96460  electronics smartphone xiaomi medium
# 99504    electronics smartphone samsung low

# %%
df_final.head()
# Out:
#                  combo  counts  product_1  product_2  price_1  price_2  \
# 28218  1004249_1003306       2    1004249    1003306   739.81   588.77
# 34074  1004767_1004833       2    1004767    1004833   254.82   174.76
# 71264  1004767_1004856       2    1004767    1004856   254.82   130.76
# 96460  4804056_1005159       2    4804056    1005159   161.98   231.41
# 99504  1004767_1005100       2    1004767    1005100   254.82   154.42
#
#                                    metadata_1  \
# 28218       electronics smartphone apple high
# 34074   electronics smartphone samsung medium
# 71264   electronics smartphone samsung medium
# 96460  electronics audio headphone apple high
# 99504   electronics smartphone samsung medium
#
#                                  metadata_2
# 28218   electronics smartphone apple medium
# 34074    electronics smartphone samsung low
# 71264    electronics smartphone samsung low
# 96460  electronics smartphone xiaomi medium
# 99504    electronics smartphone samsung low

# %%
df_final["1.1"] = df_final["metadata_1"].str.split(" ",expand=True)[0].astype('category')
df_final["1.2"] = df_final["metadata_1"].str.split(" ",expand=True)[1].astype('category')
df_final.head()
# Out:
# /tmp/ipykernel_4847/874055066.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["1.1"] = df_final["metadata_1"].str.split(" ",expand=True)[0].astype('category')
# /tmp/ipykernel_4847/874055066.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["1.2"] = df_final["metadata_1"].str.split(" ",expand=True)[1].astype('category')
#                  combo  counts  product_1  product_2  price_1  price_2  \
# 28218  1004249_1003306       2    1004249    1003306   739.81   588.77
# 34074  1004767_1004833       2    1004767    1004833   254.82   174.76
# 71264  1004767_1004856       2    1004767    1004856   254.82   130.76
# 96460  4804056_1005159       2    4804056    1005159   161.98   231.41
# 99504  1004767_1005100       2    1004767    1005100   254.82   154.42
#
#                                    metadata_1  \
# 28218       electronics smartphone apple high
# 34074   electronics smartphone samsung medium
# 71264   electronics smartphone samsung medium
# 96460  electronics audio headphone apple high
# 99504   electronics smartphone samsung medium
#
#                                  metadata_2          1.1         1.2
# 28218   electronics smartphone apple medium  electronics  smartphone
# 34074    electronics smartphone samsung low  electronics  smartphone
# 71264    electronics smartphone samsung low  electronics  smartphone
# 96460  electronics smartphone xiaomi medium  electronics       audio
# 99504    electronics smartphone samsung low  electronics  smartphone

# %%
df_final["2.1"] = df_final["metadata_2"].str.split(" ",expand=True)[0].astype('category')
df_final["2.2"] = df_final["metadata_2"].str.split(" ",expand=True)[1].astype('category')
df_final.shape
# Out:
# /tmp/ipykernel_4847/2188218553.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["2.1"] = df_final["metadata_2"].str.split(" ",expand=True)[0].astype('category')
# /tmp/ipykernel_4847/2188218553.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["2.2"] = df_final["metadata_2"].str.split(" ",expand=True)[1].astype('category')
# (125, 12)

# %%
df_final['test_1'] = df_final[['1.1', '1.2']].apply(lambda x: ' '.join(x), axis = 1)
df_final['test_2'] = df_final[['2.1', '2.2']].apply(lambda x: ' '.join(x), axis = 1)
# Out:
# /tmp/ipykernel_4847/1810607773.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['test_1'] = df_final[['1.1', '1.2']].apply(lambda x: ' '.join(x), axis = 1)
# /tmp/ipykernel_4847/1810607773.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['test_2'] = df_final[['2.1', '2.2']].apply(lambda x: ' '.join(x), axis = 1)

# %%
df_final.head()
# Out:
#                  combo  counts  product_1  product_2  price_1  price_2  \
# 28218  1004249_1003306       2    1004249    1003306   739.81   588.77
# 34074  1004767_1004833       2    1004767    1004833   254.82   174.76
# 71264  1004767_1004856       2    1004767    1004856   254.82   130.76
# 96460  4804056_1005159       2    4804056    1005159   161.98   231.41
# 99504  1004767_1005100       2    1004767    1005100   254.82   154.42
#
#                                    metadata_1  \
# 28218       electronics smartphone apple high
# 34074   electronics smartphone samsung medium
# 71264   electronics smartphone samsung medium
# 96460  electronics audio headphone apple high
# 99504   electronics smartphone samsung medium
#
#                                  metadata_2          1.1         1.2  \
# 28218   electronics smartphone apple medium  electronics  smartphone
# 34074    electronics smartphone samsung low  electronics  smartphone
# 71264    electronics smartphone samsung low  electronics  smartphone
# 96460  electronics smartphone xiaomi medium  electronics       audio
# 99504    electronics smartphone samsung low  electronics  smartphone
#
#                2.1         2.2                  test_1                  test_2
# 28218  electronics  smartphone  electronics smartphone  electronics smartphone
# 34074  electronics  smartphone  electronics smartphone  electronics smartphone
# 71264  electronics  smartphone  electronics smartphone  electronics smartphone
# 96460  electronics  smartphone       electronics audio  electronics smartphone
# 99504  electronics  smartphone  electronics smartphone  electronics smartphone

# %%
df_final_2 = df_final[df_final['test_1'] != df_final['test_2']]

# %%
df_final_2.head()
# Out:
#                   combo  counts  product_1  product_2  price_1  price_2  \
# 96460   4804056_1005159       2    4804056    1005159   161.98   231.41
# 105599  4804056_1004249       1    4804056    1004249   161.98   739.81
# 116984  3600231_5100610       1    3600231    5100610   100.38   360.34
# 127443  2701735_1307406       1    2701735    1307406  1297.27   553.39
# 135330  3701104_1004238       1    3701104    1004238   175.01  1205.23
#
#                                       metadata_1  \
# 96460     electronics audio headphone apple high
# 105599    electronics audio headphone apple high
# 116984       appliances kitchen washer midea low
# 127443  appliances kitchen refrigerators lg high
# 135330   appliances environment vacuum lg medium
#
#                                   metadata_2          1.1          1.2  \
# 96460   electronics smartphone xiaomi medium  electronics        audio
# 105599     electronics smartphone apple high  electronics        audio
# 116984       electronics clocks apple medium   appliances      kitchen
# 127443      computers notebook lenovo medium   appliances      kitchen
# 135330     electronics smartphone apple high   appliances  environment
#
#                 2.1         2.2                  test_1  \
# 96460   electronics  smartphone       electronics audio
# 105599  electronics  smartphone       electronics audio
# 116984  electronics      clocks      appliances kitchen
# 127443    computers    notebook      appliances kitchen
# 135330  electronics  smartphone  appliances environment
#
#                         test_2
# 96460   electronics smartphone
# 105599  electronics smartphone
# 116984      electronics clocks
# 127443      computers notebook
# 135330  electronics smartphone

# %%
def X_seller(X, product_id, n=5):
    X.sort_values(by='counts')
    X = X.loc[X['product_1']==product_id]
    X = X[['combo', 'counts', 'product_1', 'product_2', 'price_1', 'price_2', 'metadata_1', 'metadata_2']]
    return X

# %%
X_seller(df_final_2, 2701735)
# Out:
#                   combo  counts  product_1  product_2  price_1  price_2  \
# 127443  2701735_1307406       1    2701735    1307406  1297.27   553.39
#
#                                       metadata_1  \
# 127443  appliances kitchen refrigerators lg high
#
#                               metadata_2
# 127443  computers notebook lenovo medium

# %%
df_final_2.to_csv('x_seller.csv')

# %%
# !pwd
# Out:
# /home/cjergen/code/sailormoonvicky/eCommerce/notebooks
