# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import OneHotEncoder
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import TruncatedSVD
from sklearn.metrics.pairwise import cosine_similarity

from collections import Counter
import operator

# %%
filename = '../data/2019-Oct.csv_10%.csv'

# %%
1
# Out:
# 1

# %%
import random
p = 0.5  # 1% of the lines
# keep the header, then take only 1% of lines
# if random from [0,1] interval is greater than 0.01 the row will be skipped
df = pd.read_csv(
         filename,
         header=0, 
         skiprows=lambda i: i>0 and random.random() > p
)
df.shape
# Out:
# (2124617, 9)

# %% [markdown]
# # Preprocess

# %%
def preprocessing_feat(X, drop_event_time=False):
    if drop_event_time:
        X = X.drop("event_time", axis=1)
    
    X_preprocessed = X.dropna(subset = ['category_code', 'brand']) #tbd!!
    X_preprocessed = X_preprocessed.drop_duplicates()
    X_preprocessed['category_code'] = X_preprocessed['category_code'].str.replace('.',' ')
    return X_preprocessed

# %%
X_preprocessed = preprocessing_feat(df, drop_event_time=True)
# Out:
# /tmp/ipykernel_9601/4055017079.py:7: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   X_preprocessed['category_code'] = X_preprocessed['category_code'].str.replace('.',' ')

# %%
X_preprocessed.shape
# Out:
# (1293444, 8)

# %%
def make_column(row):
    if row["price"] < row["25%"]:
        return "low"
    elif row["price"] < row["75%"]:
        return "medium"
    else:
        return "high"

def pricing_criterion(X):
    pricing_guide = X.groupby('category_code')['price'].describe()[["25%", "75%"]].reset_index()
    X_merged = X.merge(pricing_guide, on="category_code", how="right")
    X_merged["price_category"] = X_merged.apply(lambda row: make_column(row), axis=1)
    return X_merged

# %%
X_merged = pricing_criterion(X_preprocessed)

# %%
def metadata(X):
    X['metadata'] = X[['category_code', 'brand', 'price_category']].apply(lambda x: ' '.join(x), axis = 1)
    return X

# %%
X_meta = metadata(X_merged)
X_meta.shape
# Out:
# (1293444, 12)

# %%
X_meta.head()
# Out:
#   event_type  product_id          category_id    category_code     brand  \
# 0       view    32900083  2055156924407612189  accessories bag   a-elita
# 1       view    28401176  2053013566209917945  accessories bag     karya
# 2       view    28400461  2053013566209917945  accessories bag  fabretti
# 3       view    28401054  2053013566209917945  accessories bag     karya
# 4       view    18300169  2053013558945383017  accessories bag        hp
#
#     price    user_id                          user_session    25%    75%  \
# 0    8.49  549437633  62760980-f427-42e0-a891-8b590fd54584  16.28  76.96
# 1  100.39  549348524  933c58ab-5185-44d6-94d6-c2ccb335d7f9  16.28  76.96
# 2   31.92  512406877  c1ae47b0-9ab4-4f5f-947a-2e0d80970e6c  16.28  76.96
# 3  100.39  514312434  0d0c3d87-ed6f-4f58-9b9e-2cc44b89d25c  16.28  76.96
# 4   17.82  555465687  1fa735b1-1d98-4562-9b7d-74211f89394a  16.28  76.96
#
#   price_category                         metadata
# 0            low      accessories bag a-elita low
# 1           high       accessories bag karya high
# 2         medium  accessories bag fabretti medium
# 3           high       accessories bag karya high
# 4         medium        accessories bag hp medium

# %%
X_purch = X_meta[X_meta['event_type']=='purchase']

# %%
X_purch.head()
# Out:
#     event_type  product_id          category_id    category_code    brand  \
# 336   purchase    28400931  2053013566209917945  accessories bag  respect
# 347   purchase    49800014  2126679654801604876  accessories bag   ritmix
# 560   purchase    49800017  2126679654801604876  accessories bag   ritmix
# 616   purchase    28400343  2053013566209917945  accessories bag    karya
# 635   purchase    28401078  2053013566209917945  accessories bag  respect
#
#       price    user_id                          user_session    25%    75%  \
# 336   82.11  513848273  affb8be2-7b49-4a2c-a66c-4c18142b7615  16.28  76.96
# 347   12.86  514694624  655725f6-f9ff-4088-b60b-6c8a542a72f6  16.28  76.96
# 560   12.32  512700216  d1faefa6-ce4a-474e-b952-26b0483a6cfa  16.28  76.96
# 616  100.39  522957356  29d61a4a-c1fa-4c38-acd0-8685cac830eb  16.28  76.96
# 635   66.67  547677690  b17a59b8-42c3-4c8a-ac3b-f462b83c3caa  16.28  76.96
#
#     price_category                        metadata
# 336           high    accessories bag respect high
# 347            low      accessories bag ritmix low
# 560            low      accessories bag ritmix low
# 616           high      accessories bag karya high
# 635         medium  accessories bag respect medium

# %%
def filter(X):
    df = pd.DataFrame(X.groupby('user_session').event_type.count())
    df_new = df[df['event_type']>1]
    return df_new

# %%
X_filter = filter(X_purch)

# %%
df_cross = X_purch[X_purch['user_session'].isin(X_filter.index)]

# %%
df_cross.head()
# Out:
#       event_type  product_id          category_id       category_code  \
# 33424   purchase    28715723  2053013565782098913       apparel shoes
# 44921   purchase    28718097  2053013565069067197  apparel shoes keds
# 47054   purchase    28719302  2053013565480109009  apparel shoes keds
# 47057   purchase    28715120  2053013565480109009  apparel shoes keds
# 64255   purchase    35200115  2090228413380952337   apparel underwear
#
#            brand  price    user_id                          user_session  \
# 33424    caprice  64.61  562669160  a82f9713-d470-4b5e-bb79-256b2ffdd78b
# 44921    respect  51.22  548555298  b8f60d64-f0cb-41aa-8e3c-26f21e79918f
# 47054       fila  94.98  547066883  fe1a5c19-a144-473e-8db5-5a97a4f80aa5
# 47057      baden  51.22  547066883  fe1a5c19-a144-473e-8db5-5a97a4f80aa5
# 64255  milavitsa  14.36  556897343  7b647592-c071-48d4-8a6c-54cce9eecf9a
#
#          25%     75% price_category                            metadata
# 33424  62.81  105.54         medium        apparel shoes caprice medium
# 44921  51.22  100.39         medium   apparel shoes keds respect medium
# 47054  51.22  100.39         medium      apparel shoes keds fila medium
# 47057  51.22  100.39         medium     apparel shoes keds baden medium
# 64255  14.28   31.51         medium  apparel underwear milavitsa medium

# %% [markdown]
# # Counter

# %%
df_test = pd.DataFrame(df_cross.groupby('user_session')['product_id'].apply(list).tolist())
df_test.head()
# Out:
#          0        1   2
# 0  4200545  3600952 NaN
# 1  1004961  1201466 NaN
# 2  5100722  1004767 NaN
# 3  1004833  1004579 NaN
# 4  1005138  1004856 NaN

# %%
def concat(X):
    X = X[X[0]!=X[1]]
    X['conc'] = X[0].astype(str) + '_' + X[1].astype(str)
    
    lst = list(X['conc'])
    
    a = list(Counter(lst).keys()) # equals to list(X['conc'])
    b = list(Counter(lst).values()) # counts the elements' frequency
    
    dct_1 = {a[i]: b[i] for i in range(len(a))}
    dct_2 = dict(sorted(dct_1.items(), key=operator.itemgetter(1),reverse=True))

    return pd.DataFrame.from_dict(dct_2, orient='index').reset_index().rename(columns={'index': 'combo', 0: 'counts'})

# %%
X_sell = concat(df_test)
# Out:
# /tmp/ipykernel_9601/1906696682.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['conc'] = X[0].astype(str) + '_' + X[1].astype(str)

# %%
X_sell
# Out:
#                  combo  counts
# 0      1004870_1004836       2
# 1      1003306_1002544       2
# 2      1004767_1004833       2
# 3      1004870_1004767       2
# 4      1004836_1004856       2
# ..                 ...     ...
# 141    1005115_1004258       1
# 142    1005105_1005118       1
# 143    1004565_1005003       1
# 144  28719302_28715120       1
# 145    1004767_1004750       1
#
# [146 rows x 2 columns]

# %%
def x_seller(X):
    X["product_1"] = X["combo"].str.split("_",expand=True)[0].astype('category')
    X["product_2"] = X["combo"].str.split("_",expand=True)[1].astype('category')
    return X

# %%
new_dataframe = x_seller(X_sell)

new_dataframe.product_1 = new_dataframe.product_1.apply(lambda x: int(x))
new_dataframe.product_2 = new_dataframe.product_2.apply(lambda x: int(x))

# %%
new_df_1 = new_dataframe.merge(X_meta, how='left', left_on='product_1', right_on='product_id').rename(columns={'price': 'price_1', 'metadata': 'metadata_1'})

# %%
new_df_1.head()
# Out:
#              combo  counts  product_1 product_2 event_type  product_id  \
# 0  1004870_1004836       2    1004870   1004836       view     1004870
# 1  1004870_1004836       2    1004870   1004836       view     1004870
# 2  1004870_1004836       2    1004870   1004836       view     1004870
# 3  1004870_1004836       2    1004870   1004836       view     1004870
# 4  1004870_1004836       2    1004870   1004836       view     1004870
#
#            category_id           category_code    brand  price_1    user_id  \
# 0  2053013555631882655  electronics smartphone  samsung   286.86  551658360
# 1  2053013555631882655  electronics smartphone  samsung   286.86  516414268
# 2  2053013555631882655  electronics smartphone  samsung   286.86  514715527
# 3  2053013555631882655  electronics smartphone  samsung   286.86  541967721
# 4  2053013555631882655  electronics smartphone  samsung   286.86  512730342
#
#                            user_session     25%     75% price_category  \
# 0  f5aa89f7-e4a8-4886-b564-c2ace1cb0a44  179.26  725.09         medium
# 1  e06fdaa6-6062-428d-a332-1607ec63fc17  179.26  725.09         medium
# 2  85216168-a50f-48a4-a127-4ee9cc9421e4  179.26  725.09         medium
# 3  b51df33d-d8f8-44d0-94ca-3feeced863a4  179.26  725.09         medium
# 4  403d3545-0e32-4d7d-a6ef-eb75efc7be38  179.26  725.09         medium
#
#                               metadata_1
# 0  electronics smartphone samsung medium
# 1  electronics smartphone samsung medium
# 2  electronics smartphone samsung medium
# 3  electronics smartphone samsung medium
# 4  electronics smartphone samsung medium

# %%
new_df_1 = new_df_1.drop_duplicates(['product_1','product_2'])
new_df_1.shape
# Out:
# (146, 16)

# %%
new_df_1.head()
# Out:
#                  combo  counts  product_1 product_2 event_type  product_id  \
# 0      1004870_1004836       2    1004870   1004836       view     1004870
# 10650  1003306_1002544       2    1003306   1002544       view     1003306
# 16217  1004767_1004833       2    1004767   1004833       view     1004767
# 37473  1004870_1004767       2    1004870   1004767       view     1004870
# 48123  1004836_1004856       2    1004836   1004856       view     1004836
#
#                category_id           category_code    brand  price_1  \
# 0      2053013555631882655  electronics smartphone  samsung   286.86
# 10650  2053013555631882655  electronics smartphone    apple   588.77
# 16217  2053013555631882655  electronics smartphone  samsung   254.82
# 37473  2053013555631882655  electronics smartphone  samsung   286.86
# 48123  2053013555631882655  electronics smartphone  samsung   241.19
#
#          user_id                          user_session     25%     75%  \
# 0      551658360  f5aa89f7-e4a8-4886-b564-c2ace1cb0a44  179.26  725.09
# 10650  555462420  54376386-c6a2-4a33-8271-a2cc7aa1bbe5  179.26  725.09
# 16217  551417808  3f2209fb-0fe6-4093-8486-51e52dbda8cf  179.26  725.09
# 37473  551658360  f5aa89f7-e4a8-4886-b564-c2ace1cb0a44  179.26  725.09
# 48123  546259103  6e2984c8-502e-4fe7-bbba-34087f760175  179.26  725.09
#
#       price_category                             metadata_1
# 0             medium  electronics smartphone samsung medium
# 10650         medium    electronics smartphone apple medium
# 16217         medium  electronics smartphone samsung medium
# 37473         medium  electronics smartphone samsung medium
# 48123         medium  electronics smartphone samsung medium

# %%
df_short = new_df_1[['combo', 'counts', 'product_1', 'product_2', 'price_1', 'metadata_1']]
df_short.head()
# Out:
#                  combo  counts  product_1 product_2  price_1  \
# 0      1004870_1004836       2    1004870   1004836   286.86
# 10650  1003306_1002544       2    1003306   1002544   588.77
# 16217  1004767_1004833       2    1004767   1004833   254.82
# 37473  1004870_1004767       2    1004870   1004767   286.86
# 48123  1004836_1004856       2    1004836   1004856   241.19
#
#                                   metadata_1
# 0      electronics smartphone samsung medium
# 10650    electronics smartphone apple medium
# 16217  electronics smartphone samsung medium
# 37473  electronics smartphone samsung medium
# 48123  electronics smartphone samsung medium

# %%
df_final = df_short.merge(X_meta, how='left', left_on='product_2', right_on='product_id').rename(columns={'price': 'price_2', 'metadata': 'metadata_2'}).drop_duplicates(['product_1','product_2'])

# %%
df_final
# Out:
#                     combo  counts  product_1  product_2  price_1  \
# 0         1004870_1004836       2    1004870    1004836   286.86
# 7950      1003306_1002544       2    1003306    1002544   588.77
# 17976     1004767_1004833       2    1004767    1004833   254.82
# 29508     1004870_1004767       2    1004870    1004767   286.86
# 50764     1004836_1004856       2    1004836    1004856   241.19
# ...                   ...     ...        ...        ...      ...
# 795168    1005115_1004258       1    1005115    1004258   975.57
# 799550    1005105_1005118       1    1005105    1005118  1415.48
# 801230    1004565_1005003       1    1004565    1005003   177.47
# 803541  28719302_28715120       1   28719302   28715120    94.98
# 803562    1004767_1004750       1    1004767    1004750   254.82
#
#                                    metadata_1 event_type  product_id  \
# 0       electronics smartphone samsung medium       view     1004836
# 7950      electronics smartphone apple medium       view     1002544
# 17976   electronics smartphone samsung medium       view     1004833
# 29508   electronics smartphone samsung medium       view     1004767
# 50764   electronics smartphone samsung medium       view     1004856
# ...                                       ...        ...         ...
# 795168      electronics smartphone apple high       view     1004258
# 799550      electronics smartphone apple high       view     1005118
# 801230      electronics smartphone huawei low       view     1005003
# 803541         apparel shoes keds fila medium       view    28715120
# 803562  electronics smartphone samsung medium       view     1004750
#
#                 category_id           category_code    brand  price_2  \
# 0       2053013555631882655  electronics smartphone  samsung   241.19
# 7950    2053013555631882655  electronics smartphone    apple   464.13
# 17976   2053013555631882655  electronics smartphone  samsung   174.76
# 29508   2053013555631882655  electronics smartphone  samsung   254.82
# 50764   2053013555631882655  electronics smartphone  samsung   130.76
# ...                     ...                     ...      ...      ...
# 795168  2053013555631882655  electronics smartphone    apple   735.05
# 799550  2053013555631882655  electronics smartphone    apple   975.57
# 801230  2053013555631882655  electronics smartphone   huawei   258.21
# 803541  2053013565480109009      apparel shoes keds    baden    51.22
# 803562  2053013555631882655  electronics smartphone  samsung   197.43
#
#           user_id                          user_session     25%     75%  \
# 0       546259103  6e2984c8-502e-4fe7-bbba-34087f760175  179.26  725.09
# 7950    515544667  f619453a-5696-43ba-8cd5-3752e31d811d  179.26  725.09
# 17976   519403613  36c36d74-311f-4b3a-b554-3ae63824c1ab  179.26  725.09
# 29508   551417808  3f2209fb-0fe6-4093-8486-51e52dbda8cf  179.26  725.09
# 50764   515757896  4938043e-e50f-44ad-944d-958d04df62d6  179.26  725.09
# ...           ...                                   ...     ...     ...
# 795168  540451356  66e9533a-cd23-4dfc-a335-92612d3c06a2  179.26  725.09
# 799550  513574985  ee749cd7-2ecd-4b1c-9b17-0df8c52b487c  179.26  725.09
# 801230  530102906  0c74e0cc-d340-46ab-a2ec-22991081648b  179.26  725.09
# 803541  548016731  50bd640a-55ea-440b-8b2f-5fa4b4f9d39c   51.22  100.39
# 803562  515553990  4312ec52-14bf-4478-a9cf-32801fe327f7  179.26  725.09
#
#        price_category                             metadata_2
# 0              medium  electronics smartphone samsung medium
# 7950           medium    electronics smartphone apple medium
# 17976             low     electronics smartphone samsung low
# 29508          medium  electronics smartphone samsung medium
# 50764             low     electronics smartphone samsung low
# ...               ...                                    ...
# 795168           high      electronics smartphone apple high
# 799550           high      electronics smartphone apple high
# 801230         medium   electronics smartphone huawei medium
# 803541         medium        apparel shoes keds baden medium
# 803562         medium  electronics smartphone samsung medium
#
# [146 rows x 18 columns]

# %% [markdown]
# # Final recommendation

# %%
df_final = df_final[['combo', 'counts', 'product_1', 'product_2', 'price_1', 'price_2', 'metadata_1', 'metadata_2']]

# %%
df_final
# Out:
#                     combo  counts  product_1  product_2  price_1  price_2  \
# 0         1004870_1004836       2    1004870    1004836   286.86   241.19
# 7950      1003306_1002544       2    1003306    1002544   588.77   464.13
# 17976     1004767_1004833       2    1004767    1004833   254.82   174.76
# 29508     1004870_1004767       2    1004870    1004767   286.86   254.82
# 50764     1004836_1004856       2    1004836    1004856   241.19   130.76
# ...                   ...     ...        ...        ...      ...      ...
# 795168    1005115_1004258       1    1005115    1004258   975.57   735.05
# 799550    1005105_1005118       1    1005105    1005118  1415.48   975.57
# 801230    1004565_1005003       1    1004565    1005003   177.47   258.21
# 803541  28719302_28715120       1   28719302   28715120    94.98    51.22
# 803562    1004767_1004750       1    1004767    1004750   254.82   197.43
#
#                                    metadata_1  \
# 0       electronics smartphone samsung medium
# 7950      electronics smartphone apple medium
# 17976   electronics smartphone samsung medium
# 29508   electronics smartphone samsung medium
# 50764   electronics smartphone samsung medium
# ...                                       ...
# 795168      electronics smartphone apple high
# 799550      electronics smartphone apple high
# 801230      electronics smartphone huawei low
# 803541         apparel shoes keds fila medium
# 803562  electronics smartphone samsung medium
#
#                                    metadata_2
# 0       electronics smartphone samsung medium
# 7950      electronics smartphone apple medium
# 17976      electronics smartphone samsung low
# 29508   electronics smartphone samsung medium
# 50764      electronics smartphone samsung low
# ...                                       ...
# 795168      electronics smartphone apple high
# 799550      electronics smartphone apple high
# 801230   electronics smartphone huawei medium
# 803541        apparel shoes keds baden medium
# 803562  electronics smartphone samsung medium
#
# [146 rows x 8 columns]

# %%
df_final = df_final[df_final['metadata_1'] != df_final['metadata_2']]

# %%
df_final.head()
# Out:
#                  combo  counts  product_1  product_2  price_1  price_2  \
# 17976  1004767_1004833       2    1004767    1004833   254.82   174.76
# 50764  1004836_1004856       2    1004836    1004856   241.19   130.76
# 74757  4200545_3600952       1    4200545    3600952   437.57   423.89
# 74818  1004961_1201466       1    1004961    1201466   179.36   237.27
# 75119  5100722_1004767       1    5100722    1004767   169.62   254.82
#
#                                               metadata_1  \
# 17976              electronics smartphone samsung medium
# 50764              electronics smartphone samsung medium
# 74757  appliances environment air_conditioner elenber...
# 74818                 electronics smartphone oppo medium
# 75119                   electronics clocks huawei medium
#
#                                    metadata_2
# 17976      electronics smartphone samsung low
# 50764      electronics smartphone samsung low
# 74757  appliances kitchen washer samsung high
# 74818       electronics tablet samsung medium
# 75119   electronics smartphone samsung medium

# %%
df_final.head()
# Out:
#                  combo  counts  product_1  product_2  price_1  price_2  \
# 17976  1004767_1004833       2    1004767    1004833   254.82   174.76
# 50764  1004836_1004856       2    1004836    1004856   241.19   130.76
# 74757  4200545_3600952       1    4200545    3600952   437.57   423.89
# 74818  1004961_1201466       1    1004961    1201466   179.36   237.27
# 75119  5100722_1004767       1    5100722    1004767   169.62   254.82
#
#                                               metadata_1  \
# 17976              electronics smartphone samsung medium
# 50764              electronics smartphone samsung medium
# 74757  appliances environment air_conditioner elenber...
# 74818                 electronics smartphone oppo medium
# 75119                   electronics clocks huawei medium
#
#                                    metadata_2
# 17976      electronics smartphone samsung low
# 50764      electronics smartphone samsung low
# 74757  appliances kitchen washer samsung high
# 74818       electronics tablet samsung medium
# 75119   electronics smartphone samsung medium

# %%
df_final["1.1"] = df_final["metadata_1"].str.split(" ",expand=True)[0].astype('category')
df_final["1.2"] = df_final["metadata_1"].str.split(" ",expand=True)[1].astype('category')
df_final.head()
# Out:
# /tmp/ipykernel_9601/874055066.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["1.1"] = df_final["metadata_1"].str.split(" ",expand=True)[0].astype('category')
# /tmp/ipykernel_9601/874055066.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["1.2"] = df_final["metadata_1"].str.split(" ",expand=True)[1].astype('category')
#                  combo  counts  product_1  product_2  price_1  price_2  \
# 17976  1004767_1004833       2    1004767    1004833   254.82   174.76
# 50764  1004836_1004856       2    1004836    1004856   241.19   130.76
# 74757  4200545_3600952       1    4200545    3600952   437.57   423.89
# 74818  1004961_1201466       1    1004961    1201466   179.36   237.27
# 75119  5100722_1004767       1    5100722    1004767   169.62   254.82
#
#                                               metadata_1  \
# 17976              electronics smartphone samsung medium
# 50764              electronics smartphone samsung medium
# 74757  appliances environment air_conditioner elenber...
# 74818                 electronics smartphone oppo medium
# 75119                   electronics clocks huawei medium
#
#                                    metadata_2          1.1          1.2
# 17976      electronics smartphone samsung low  electronics   smartphone
# 50764      electronics smartphone samsung low  electronics   smartphone
# 74757  appliances kitchen washer samsung high   appliances  environment
# 74818       electronics tablet samsung medium  electronics   smartphone
# 75119   electronics smartphone samsung medium  electronics       clocks

# %%
df_final["2.1"] = df_final["metadata_2"].str.split(" ",expand=True)[0].astype('category')
df_final["2.2"] = df_final["metadata_2"].str.split(" ",expand=True)[1].astype('category')
df_final.shape
# Out:
# /tmp/ipykernel_9601/2188218553.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["2.1"] = df_final["metadata_2"].str.split(" ",expand=True)[0].astype('category')
# /tmp/ipykernel_9601/2188218553.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["2.2"] = df_final["metadata_2"].str.split(" ",expand=True)[1].astype('category')
# (93, 12)

# %%
df_final['test_1'] = df_final[['1.1', '1.2']].apply(lambda x: ' '.join(x), axis = 1)
df_final['test_2'] = df_final[['2.1', '2.2']].apply(lambda x: ' '.join(x), axis = 1)
# Out:
# /tmp/ipykernel_9601/1810607773.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['test_1'] = df_final[['1.1', '1.2']].apply(lambda x: ' '.join(x), axis = 1)
# /tmp/ipykernel_9601/1810607773.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['test_2'] = df_final[['2.1', '2.2']].apply(lambda x: ' '.join(x), axis = 1)

# %%
df_final.head()
# Out:
#                  combo  counts  product_1  product_2  price_1  price_2  \
# 17976  1004767_1004833       2    1004767    1004833   254.82   174.76
# 50764  1004836_1004856       2    1004836    1004856   241.19   130.76
# 74757  4200545_3600952       1    4200545    3600952   437.57   423.89
# 74818  1004961_1201466       1    1004961    1201466   179.36   237.27
# 75119  5100722_1004767       1    5100722    1004767   169.62   254.82
#
#                                               metadata_1  \
# 17976              electronics smartphone samsung medium
# 50764              electronics smartphone samsung medium
# 74757  appliances environment air_conditioner elenber...
# 692344       electronics smartphone apple high  electronics        audio
# 707154   electronics smartphone samsung medium   appliances      kitchen
# 728160       electronics smartphone apple high    computers     notebook
#
#                 2.1             2.2                  test_1  \
# 74757    appliances         kitchen  appliances environment
# 74818   electronics          tablet  electronics smartphone
# 75119   electronics      smartphone      electronics clocks
# 121175  electronics           video      appliances kitchen
# 150165   appliances            iron  appliances environment
# 197741  electronics           video  electronics smartphone
# 201638  electronics           video      appliances kitchen
# 224451  electronics      smartphone      electronics clocks
# 242500  electronics      smartphone      computers notebook
# 253467  electronics      smartphone       electronics audio
# 300015  electronics      smartphone        auto accessories
# 330172  electronics       telephone  electronics smartphone
# 330507  electronics           video  electronics smartphone
# 370137  electronics      smartphone      appliances kitchen
# 397519         kids          skates      computers notebook
# 397754  electronics      smartphone       electronics audio
# 441118  electronics           audio       apparel underwear
# 441161  electronics      smartphone       electronics audio
# 508388   appliances  sewing_machine         appliances iron
# 518364  electronics      smartphone       electronics audio
# 550520    computers        notebook       computers desktop
# 551848  electronics      smartphone      computers notebook
# 562455   appliances         kitchen           apparel shoes
# 571226  electronics      smartphone    computers components
# 609706  electronics      smartphone      electronics clocks
# 617200  electronics      smartphone       electronics audio
# 627807  electronics      smartphone         appliances iron
# 657600  electronics           video  electronics smartphone
# 660180  electronics      smartphone           apparel shoes
# 662541  electronics       telephone  electronics smartphone
# 687932  electronics          clocks       electronics audio
# 692344  electronics      smartphone       electronics audio
# 707154  electronics      smartphone      appliances kitchen
# 728160  electronics      smartphone      computers notebook
#
#                            test_2
# 74757          appliances kitchen
# 74818          electronics tablet
# 75119      electronics smartphone
# 121175          electronics video
# 150165            appliances iron
# 197741          electronics video
# 201638          electronics video
# 224451     electronics smartphone
# 242500     electronics smartphone
# 253467     electronics smartphone
# 300015     electronics smartphone
# 330172      electronics telephone
# 330507          electronics video
# 370137     electronics smartphone
# 397519                kids skates
# 397754     electronics smartphone
# 441118          electronics audio
# 441161     electronics smartphone
# 508388  appliances sewing_machine
# 518364     electronics smartphone
# 550520         computers notebook
# 551848     electronics smartphone
# 562455         appliances kitchen
# 571226     electronics smartphone
# 609706     electronics smartphone
# 617200     electronics smartphone
# 627807     electronics smartphone
# 657600          electronics video
# 660180     electronics smartphone
# 662541      electronics telephone
# 687932         electronics clocks
# 692344     electronics smartphone
# 707154     electronics smartphone
# 728160     electronics smartphone

# %%
def X_seller(X, product_id, n=2):
    X.sort_values(by='counts')
    X = X.loc[X['product_1']==product_id]
    X = X[['combo', 'counts', 'product_1', 'product_2', 'price_1', 'price_2', 'metadata_1', 'metadata_2']]
    return X

# %%
X_seller(df_final_2, 4802036)
# Out:
#                   combo  counts  product_1  product_2  price_1  price_2  \
# 253467  4802036_1005135       1    4802036    1005135   171.56  1747.79
#
#                                     metadata_1  \
# 253467  electronics audio headphone apple high
#
#                                metadata_2
# 253467  electronics smartphone apple high
