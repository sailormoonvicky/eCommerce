# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import OneHotEncoder
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import TruncatedSVD
from sklearn.metrics.pairwise import cosine_similarity

from collections import Counter
import operator

# %%
! pwd
# Out:
# /home/cjergen/code/sailormoonvicky/eCommerce/notebooks

# %%
filename = '../data/2019-Oct.csv_10%.csv'

# %%
import random
p = 1  # 1% of the lines
# keep the header, then take only 1% of lines
# if random from [0,1] interval is greater than 0.01 the row will be skipped
df = pd.read_csv(
         filename,
         header=0, 
         skiprows=lambda i: i>0 and random.random() > p
)
df.shape
# Out:
# (4248118, 9)

# %%
df.head()
# Out:
#                 event_time event_type  product_id          category_id  \
# 0  2019-10-01 00:00:17 UTC       view    23100006  2053013561638126333
# 1  2019-10-01 00:00:20 UTC       view     4803399  2053013554658804075
# 2  2019-10-01 00:00:23 UTC       view     6200260  2053013552293216471
# 3  2019-10-01 00:00:58 UTC       view     4802639  2053013554658804075
# 4  2019-10-01 00:01:11 UTC       view     1004836  2053013555631882655
#
#                        category_code    brand   price    user_id  \
# 0                                NaN      NaN  357.79  513642368
# 1        electronics.audio.headphone      jbl   33.21  555428858
# 2  appliances.environment.air_heater    midea   47.62  538645907
# 3        electronics.audio.headphone     sony  218.77  514808401
# 4             electronics.smartphone  samsung  241.19  546259103
#
#                            user_session
# 0  17566c27-0a8f-4506-9f30-c6a2ccbf583b
# 1  8a6afed4-77f8-40c9-8e76-e062b28216ce
# 2  7d9a8784-7b6c-426e-9924-9f688812fd71
# 3  1877639d-46a4-44f8-bae9-a14456952240
# 4  6e2984c8-502e-4fe7-bbba-34087f760175

# %% [markdown]
# # Preprocess

# %%
def preprocessing_x_sell(X):
    X_preprocessed = X.dropna(subset = ['category_code', 'brand']) #tbd!!
    X_preprocessed = X_preprocessed.drop_duplicates()
    X_purch = X_preprocessed[X_preprocessed['event_type']=='purchase']
    return X_purch

# %%
X_purch = preprocessing_x_sell(df)
X_purch.shape
# Out:
# (54716, 9)

# %%
X_purch
# Out:
#                       event_time event_type  product_id          category_id  \
# 156      2019-10-01 02:19:34 UTC   purchase     1005104  2053013555631882655
# 173      2019-10-01 02:20:16 UTC   purchase     4700419  2053013560899928785
# 512      2019-10-01 02:28:29 UTC   purchase     1004794  2053013555631882655
# 569      2019-10-01 02:29:40 UTC   purchase     1004750  2053013555631882655
# 663      2019-10-01 02:31:18 UTC   purchase    12400121  2053013556252639687
# ...                          ...        ...         ...                  ...
# 4247626  2019-10-31 23:18:55 UTC   purchase     1004249  2053013555631882655
# 4247744  2019-10-31 23:29:08 UTC   purchase    12300078  2053013556311359947
# 4247867  2019-10-31 23:38:58 UTC   purchase     1005182  2053013555631882655
# 4247931  2019-10-31 23:44:44 UTC   purchase     1004249  2053013555631882655
# 4248076  2019-10-31 23:56:03 UTC   purchase     1003306  2053013555631882655
#
#                           category_code    brand    price    user_id  \
# 156              electronics.smartphone    apple   975.57  555160488
# 173      auto.accessories.videoregister   sho-me   141.86  512550575
# 512              electronics.smartphone   xiaomi   241.96  555420273
# 569              electronics.smartphone  samsung   197.43  512592316
# 663            construction.tools.drill   alteco    45.82  516201000
# ...                                 ...      ...      ...        ...
# 4247626          electronics.smartphone    apple   722.40  528350072
# 4247744        construction.tools.drill    bosch    96.76  550885932
# 4247867          electronics.smartphone  samsung  1029.34  545950136
# 4247931          electronics.smartphone    apple   722.40  533364737
# 4248076          electronics.smartphone    apple   577.89  512717356
#
#                                  user_session
# 156      a1395546-c124-456c-9752-0f5cf883c63d
# 173      84f21dc3-df18-4cf3-accd-bcd9655891ca
# 512      35954daf-bd58-45c6-b22a-40f369f77ca2
# 569      2f8c3cd6-2b93-4440-bd72-3c36f4a2fd6c
# 663      2a0abd92-f425-4ec0-882f-9fb5db4b192a
# ...                                       ...
# 4247626  592de524-5929-4fa3-94be-dbae6c59a0f2
# 4247744  7c8c0c0c-bc89-40dc-91f5-94550e291e0b
# 4247867  53b5858a-3bf8-47eb-9739-f9a5b20bbc28
# 4247931  3eb9f473-ca49-44f3-8669-4aaa9fd22a97
# 4248076  f35ac37c-9573-4e30-b3d9-c09bb0b95a2b
#
# [54716 rows x 9 columns]

# %%
def filter(X):
    df = pd.DataFrame(X.groupby('user_session').event_type.count())
    df_new = df[df['event_type']>1]
    return df_new

# %%
X_filter = filter(X_purch)

# %%
X_filter.head()
# Out:
#                                       event_type
# user_session
# 004cbcc0-9763-49bd-a8a7-568e9003648f           2
# 00794112-3575-46b6-912b-42e8df0dc78b           2
# 0083e17d-90aa-4c03-a46e-ee71dea54f26           2
# 00848298-2ce1-4017-b488-cbe1ff454039           2
# 00848f4f-1fd4-4b7c-84ed-1dacc63bd352           2

# %%
df_cross = X_purch[X_purch['user_session'].isin(X_filter.index)]

# %%
df_cross.head()
# Out:
#                    event_time event_type  product_id          category_id  \
# 2871  2019-10-01 03:06:10 UTC   purchase     1306310  2053013558920217191
# 2998  2019-10-01 03:07:44 UTC   purchase     1005105  2053013555631882655
# 3532  2019-10-01 03:14:32 UTC   purchase     1002544  2053013555631882655
# 3688  2019-10-01 03:16:37 UTC   purchase     1002544  2053013555631882655
# 3755  2019-10-01 03:17:29 UTC   purchase     1002544  2053013555631882655
#
#                category_code  brand    price    user_id  \
# 2871      computers.notebook  apple  1352.42  542966898
# 2998  electronics.smartphone  apple  1415.48  542966898
# 3532  electronics.smartphone  apple   464.08  554090147
# 3688  electronics.smartphone  apple   464.08  554090147
# 3755  electronics.smartphone  apple   464.08  554090147
#
#                               user_session
# 2871  a6a87556-4169-4a7c-b68e-2e71379f5397
# 2998  a6a87556-4169-4a7c-b68e-2e71379f5397
# 3532  c5633b76-2109-40a7-88f6-0260feebd9fd
# 3688  c5633b76-2109-40a7-88f6-0260feebd9fd
# 3755  c5633b76-2109-40a7-88f6-0260feebd9fd

# %% [markdown]
# # Counter

# %%
df_test = pd.DataFrame(df_cross.groupby('user_session')['product_id'].apply(list).tolist())
df_test.head()
# Out:
#           0         1   2   3   4   5   6   7   8
# 0  12400037  12400037 NaN NaN NaN NaN NaN NaN NaN
# 1   4200545   3600952 NaN NaN NaN NaN NaN NaN NaN
# 2   1004961   1201466 NaN NaN NaN NaN NaN NaN NaN
# 3   1306316   1306315 NaN NaN NaN NaN NaN NaN NaN
# 4   1004249   1004249 NaN NaN NaN NaN NaN NaN NaN

# %%
def concat(X):
    X = X[X[0]!=X[1]]
    X['conc'] = X[0].astype(str) + '_' + X[1].astype(str)
    
    lst = list(X['conc'])
    
    a = list(Counter(lst).keys()) # equals to list(X['conc'])
    b = list(Counter(lst).values()) # counts the elements' frequency
    
    dct_1 = {a[i]: b[i] for i in range(len(a))}
    dct_2 = dict(sorted(dct_1.items(), key=operator.itemgetter(1),reverse=True))

    return pd.DataFrame.from_dict(dct_2, orient='index').reset_index().rename(columns={'index': 'combo', 0: 'counts'})

# %%
X_sell = concat(df_test)
# Out:
# /tmp/ipykernel_18891/327967530.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['conc'] = X[0].astype(str) + '_' + X[1].astype(str)

# %%
X_sell
# Out:
#                  combo  counts
# 0      1004767_1004856       6
# 1      1004870_1004767       5
# 2      1004833_1004856       5
# 3      1004767_1004833       4
# 4      1004873_1004767       3
# ..                 ...     ...
# 498    1004659_1004873       1
# 499  28719302_28715597       1
# 500    1004767_1004750       1
# 501    1002629_1004838       1
# 502    1801723_4804295       1
#
# [503 rows x 2 columns]

# %%
def x_seller(X):
    X["product_1"] = X["combo"].str.split("_",expand=True)[0].astype('category')
    X["product_2"] = X["combo"].str.split("_",expand=True)[1].astype('category')
    return X

# %%
new_dataframe = x_seller(X_sell)

new_dataframe.product_1 = new_dataframe.product_1.apply(lambda x: int(x))
new_dataframe.product_2 = new_dataframe.product_2.apply(lambda x: int(x))

# %%
new_dataframe.head()
# Out:
#              combo  counts product_1 product_2
# 0  1004767_1004856       6   1004767   1004856
# 1  1004870_1004767       5   1004870   1004767
# 2  1004833_1004856       5   1004833   1004856
# 3  1004767_1004833       4   1004767   1004833
# 4  1004873_1004767       3   1004873   1004767

# %%
new_df_1 = new_dataframe.merge(df, how='left', left_on='product_1', right_on='product_id').rename(columns={'price': 'price_1', 'category_code': 'category_code_1', 'brand': 'brand_1'})

# %%
new_df_1 = new_df_1.drop_duplicates(['product_1','product_2'])
new_df_1.head()
# Out:
#                   combo  counts  product_1 product_2               event_time  \
# 0       1004767_1004856       6    1004767   1004856  2019-10-01 00:02:15 UTC
# 44076   1004870_1004767       5    1004870   1004767  2019-10-01 02:19:38 UTC
# 66105   1004833_1004856       5    1004833   1004856  2019-10-01 02:23:16 UTC
# 90011   1004767_1004833       4    1004767   1004833  2019-10-01 00:02:15 UTC
# 134087  1004873_1004767       3    1004873   1004767  2019-10-01 02:20:27 UTC
#
#        event_type  product_id          category_id         category_code_1  \
# 0            view     1004767  2053013555631882655  electronics.smartphone
# 44076        view     1004870  2053013555631882655  electronics.smartphone
# 66105        view     1004833  2053013555631882655  electronics.smartphone
# 90011        view     1004767  2053013555631882655  electronics.smartphone
# 134087       view     1004873  2053013555631882655  electronics.smartphone
#
#         brand_1  price_1    user_id                          user_session
# 0       samsung   254.82  551417808  3f2209fb-0fe6-4093-8486-51e52dbda8cf
# 44076   samsung   286.86  512740727  20e584bf-6461-4940-a774-1ff1110c633b
# 66105   samsung   174.76  550422448  f9e45568-7f95-4367-8383-7dfdbd5c1791
# 90011   samsung   254.82  551417808  3f2209fb-0fe6-4093-8486-51e52dbda8cf
# 134087  samsung   388.81  512740727  20e584bf-6461-4940-a774-1ff1110c633b

# %%
new_df_2 = new_df_1.merge(df, how='left', left_on='product_2', right_on='product_id')

# %%
df_short = new_df_1[['combo', 'counts', 'product_1', 'product_2', 'price_1', 'category_code_1', 'brand_1']]
df_short.head()
# Out:
#                   combo  counts  product_1 product_2  price_1  \
# 0       1004767_1004856       6    1004767   1004856   254.82
# 44076   1004870_1004767       5    1004870   1004767   286.86
# 66105   1004833_1004856       5    1004833   1004856   174.76
# 90011   1004767_1004833       4    1004767   1004833   254.82
# 134087  1004873_1004767       3    1004873   1004767   388.81
#
#                category_code_1  brand_1
# 0       electronics.smartphone  samsung
# 44076   electronics.smartphone  samsung
# 66105   electronics.smartphone  samsung
# 90011   electronics.smartphone  samsung
# 134087  electronics.smartphone  samsung

# %%
df_final = df_short.merge(df, how='left', left_on='product_2', right_on='product_id').rename(columns={'price': 'price_2', 'category_code': 'category_code_2', 'brand': 'brand_2'}).drop_duplicates(['product_1','product_2'])

# %% [markdown]
# # Final recommendation

# %%
df_final = df_final[['combo', 'counts', 'product_1', 'product_2', 'price_1', 'price_2', 'category_code_1', 'brand_1', 'category_code_2', 'brand_2']]

# %%
df_final.head()
# Out:
#                   combo  counts  product_1  product_2  price_1  price_2  \
# 0       1004767_1004856       6    1004767    1004856   254.82   130.76
# 49567   1004870_1004767       5    1004870    1004767   286.86   254.82
# 93643   1004833_1004856       5    1004833    1004856   174.76   130.76
# 143210  1004767_1004833       4    1004767    1004833   254.82   174.76
# 167116  1004873_1004767       3    1004873    1004767   388.81   254.82
#
#                category_code_1  brand_1         category_code_2  brand_2
# 0       electronics.smartphone  samsung  electronics.smartphone  samsung
# 49567   electronics.smartphone  samsung  electronics.smartphone  samsung
# 93643   electronics.smartphone  samsung  electronics.smartphone  samsung
# 143210  electronics.smartphone  samsung  electronics.smartphone  samsung
# 167116  electronics.smartphone  samsung  electronics.smartphone  samsung

# %%
df_final['category_code_1'] = df_final['category_code_1'].str.replace('.',' ')
df_final['category_code_2'] = df_final['category_code_2'].str.replace('.',' ')

df_final.head()
# Out:
# /tmp/ipykernel_18891/401160313.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df_final['category_code_1'] = df_final['category_code_1'].str.replace('.',' ')
# /tmp/ipykernel_18891/401160313.py:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df_final['category_code_2'] = df_final['category_code_2'].str.replace('.',' ')
#                   combo  counts  product_1  product_2  price_1  price_2  \
# 0       1004767_1004856       6    1004767    1004856   254.82   130.76
# 49567   1004870_1004767       5    1004870    1004767   286.86   254.82
# 93643   1004833_1004856       5    1004833    1004856   174.76   130.76
# 143210  1004767_1004833       4    1004767    1004833   254.82   174.76
# 167116  1004873_1004767       3    1004873    1004767   388.81   254.82
#
#                category_code_1  brand_1         category_code_2  brand_2
# 0       electronics smartphone  samsung  electronics smartphone  samsung
# 49567   electronics smartphone  samsung  electronics smartphone  samsung
# 93643   electronics smartphone  samsung  electronics smartphone  samsung
# 143210  electronics smartphone  samsung  electronics smartphone  samsung
# 167116  electronics smartphone  samsung  electronics smartphone  samsung

# %%
df_final
# Out:
#                      combo  counts  product_1  product_2  price_1  price_2  \
# 0          1004767_1004856       6    1004767    1004856   254.82   130.76
# 49567      1004870_1004767       5    1004870    1004767   286.86   254.82
# 93643      1004833_1004856       5    1004833    1004856   174.76   130.76
# 143210     1004767_1004833       4    1004767    1004833   254.82   174.76
# 167116     1004873_1004767       3    1004873    1004767   388.81   254.82
# ...                    ...     ...        ...        ...      ...      ...
# 4767822    1004659_1004873       1    1004659    1004873   787.18   388.81
# 4783228  28719302_28715597       1   28719302   28715597    94.98   100.36
# 4783245    1004767_1004750       1    1004767    1004750   254.82   197.43
# 4795246    1002629_1004838       1    1002629    1004838   377.29   179.38
# 4806197    1801723_4804295       1    1801723    4804295   145.13    23.13
#
#                 category_code_1  brand_1              category_code_2  brand_2
# 0        electronics smartphone  samsung       electronics smartphone  samsung
# 49567    electronics smartphone  samsung       electronics smartphone  samsung
# 93643    electronics smartphone  samsung       electronics smartphone  samsung
# 143210   electronics smartphone  samsung       electronics smartphone  samsung
# 167116   electronics smartphone  samsung       electronics smartphone  samsung
# ...                         ...      ...                          ...      ...
# 4767822  electronics smartphone  samsung       electronics smartphone  samsung
# 4783228      apparel shoes keds     fila           apparel shoes keds     fila
# 4783245  electronics smartphone  samsung       electronics smartphone  samsung
# 4795246  electronics smartphone    apple       electronics smartphone     oppo
# 4806197    electronics video tv      tcl  electronics audio headphone   xiaomi
#
# [503 rows x 10 columns]

# %%
df_final['metadata_1'] = df_final['category_code_1'] + ' ' +  df_final['brand_1']
df_final['metadata_2'] = df_final['category_code_2'] + ' ' +  df_final['brand_2']

# %%
df_final.head()
# Out:
#                   combo  counts  product_1  product_2  price_1  price_2  \
# 0       1004767_1004856       6    1004767    1004856   254.82   130.76
# 49567   1004870_1004767       5    1004870    1004767   286.86   254.82
# 93643   1004833_1004856       5    1004833    1004856   174.76   130.76
# 143210  1004767_1004833       4    1004767    1004833   254.82   174.76
# 167116  1004873_1004767       3    1004873    1004767   388.81   254.82
#
#                category_code_1  brand_1         category_code_2  brand_2  \
# 0       electronics smartphone  samsung  electronics smartphone  samsung
# 49567   electronics smartphone  samsung  electronics smartphone  samsung
# 93643   electronics smartphone  samsung  electronics smartphone  samsung
# 143210  electronics smartphone  samsung  electronics smartphone  samsung
# 167116  electronics smartphone  samsung  electronics smartphone  samsung
#
#                             metadata_1                      metadata_2
# 0       electronics smartphone samsung  electronics smartphone samsung
# 49567   electronics smartphone samsung  electronics smartphone samsung
# 93643   electronics smartphone samsung  electronics smartphone samsung
# 143210  electronics smartphone samsung  electronics smartphone samsung
# 167116  electronics smartphone samsung  electronics smartphone samsung

# %%
df_final = df_final[df_final['metadata_1'] != df_final['metadata_2']]

# %%
df_final.head(50)
# Out:
#                      combo  counts  product_1  product_2  price_1  price_2  \
# 211192     1002544_1004767       3    1002544    1004767   464.13   254.82
# 322353     1002633_1004767       3    1002633    1004767   360.08   254.82
# 641784     1002544_1004873       2    1002544    1004873   464.13   388.81
# 764197     1004249_4804055       2    1004249    4804055   739.81   189.91
# 829605     1004249_1004875       2    1004249    1004875   739.81   388.68
# 833719     1002524_1004767       2    1002524    1004767   515.67   254.82
# 889392     4200545_3600952       1    4200545    3600952   437.57   423.89
# 889529     1004961_1201466       1    1004961    1201466   179.36   237.27
# 890265     5100722_1004767       1    5100722    1004767   169.62   254.82
# 972243     1005015_1005175       1    1005015    1005175   604.88   643.23
# 972676     1004809_1004258       1    1004809    1004258   125.58   735.05
# 981700    11300053_1005160       1   11300053    1005160    17.25   231.41
# 1001454    1004833_1004579       1    1004833    1004579   174.76    94.73
